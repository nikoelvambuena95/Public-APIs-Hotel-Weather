# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\nikoe\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\nikoe\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude

from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
print(api_key)
# Out:
# 54f6f5bb1a7c4610462289caa0693a66

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create an empty list to store JSON responses
response_json = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 601

# %%
# Build query URL
queryUrl = "http://api.openweathermap.org/data/2.5/weather?" + "appid=" + api_key + "&q="

# %%
# creating dataframe wtih test_cities
test_cities = ['acapulco', 'jamestown', 'dali', 'malatya', 'manila', 'pevek', 'cidreira']
responses = []
city_name = []
latitude = []
temperature = []
humidity = []
clouds = []
wind = []


for city in cities:
    weather_data = requests.get(queryUrl + city).json()
    responses.append(weather_data)
    try:
        city_name.append(weather_data['name'])
        latitude.append(weather_data['coord']['lat'])
        temperature.append(weather_data['main']['temp'])
        humidity.append(weather_data['main']['humidity'])
        clouds.append(weather_data['clouds']['all'])
        wind.append(weather_data['wind']['speed'])
        print(f'{city} found')
    except:
        print(f'**{city} not found**')
        pass
# Out:
# yellowknife found
# ushuaia found
# luderitz found
# zonguldak found
# **ondorhaan not found**
# seoul found
# gondar found
# richfield found
# kahului found
# cidreira found
# **belushya guba not found**
# saint-francois found
# atuona found
# souillac found
# **marcona not found**
# sept-iles found
# mahebourg found
# codrington found
# pevek found
# rikitea found
# norman wells found
# bluff found
# kadoma found
# tasiilaq found
# tiksi found
# maputo found
# albany found
# sitka found
# carlyle found
# mehamn found
# masunga found
# avarua found
# qaanaaq found
# carnarvon found
# **sentyabrskiy not found**
# vaini found
# sindor found
# quchan found
# deputatskiy found
# taltal found
# **tsihombe not found**
# makasar found
# **vaitupu not found**
# show low found
# ribeira grande found
# myingyan found
# kodiak found
# butaritari found
# **nizhneyansk not found**
# doha found
# chokurdakh found
# talnakh found
# port alfred found
# chara found
# hilo found
# padang found
# ust-maya found
# chipinge found
# maicao found
# busselton found
# saint-philippe found
# nampula found
# provideniya found
# **fort saint john not found**
# pisco found
# broken hill found
# bredasdorp found
# nikolskoye found
# shingu found
# esperance found
# erenhot found
# kavieng found
# arraial do cabo found
# batagay-alyta found
# katsuura found
# punta arenas found
# **bargal not found**
# praia da vitoria found
# charlestown found
# ponta do sol found
# tuatapere found
# kashira found
# toul found
# grootfontein found
# fort nelson found
# grand gaube found
# cayenne found
# anshun found
# lavrentiya found
# lichuan found
# puerto leguizamo found
# **taolanaro not found**
# dikson found
# kilindoni found
# moberly found
# spas-demensk found
# ancud found
# hobart found
# casa nova found
# hermanus found
# namibe found
# bathsheba found
# **grand river south east not found**
# ambikapur found
# roald found
# barrow found
# **samusu not found**
# georgetown found
# alice springs found
# bethel found
# vardo found
# kenai found
# bengkulu found
# new norfolk found
# xining found
# santa rosa found
# khandyga found
# alofi found
# east london found
# sidney found
# cabedelo found
# **saleaula not found**
# torbay found
# tura found
# chuy found
# komsomolets found
# port elizabeth found
# ialibu found
# saskylakh found
# saint-pierre found
# aklavik found
# manzhouli found
# cotonou found
# fort erie found
# russkaya polyana found
# picui found
# bambous virieux found
# cape town found
# castro found
# pilar found
# jiuquan found
# bilma found
# hithadhoo found
# raha found
# altamira found
# **dianopolis not found**
# jining found
# guskhara found
# znamensk found
# chhatapur found
# kangasala found
# esil found
# coswig found
# **grand centre not found**
# finschhafen found
# oriximina found
# axim found
# salta found
# hede found
# yeniseysk found
# xuzhou found
# elliot lake found
# killybegs found
# rivers found
# kutum found
# barpali found
# weligama found
# rodos found
# bartica found
# port-cartier found
# sambo creek found
# wuwei found
# hun found
# prince rupert found
# maningrida found
# altay found
# san jeronimo found
# marsabit found
# treinta y tres found
# pasighat found
# mahanoro found
# kitimat found
# **potgietersrus not found**
# oktyabrskoye found
# **jiroft not found**
# tulsipur found
# vuktyl found
# eydhafushi found
# duncan found
# sembakung found
# vila franca do campo found
# hami found
# napasar found
# wheatley found
# santa fe found
# eskilstuna found
# kasempa found
# papetoai found
# netarhat found
# antofagasta found

# %%
#print(responses)

# %%
weather_df = pd.DataFrame({
    'City': city_name,
    'Latitude': latitude,
    'Temperature': temperature,
    'Humidity': humidity,
    'Cloudiness': clouds,
    'Wind (MPH)': wind
})

weather_df
# Out:
#             City  Latitude  Temperature  Humidity  Cloudiness  Wind (MPH)
# 0    Yellowknife   62.4560       271.00        93          90        2.06
# 1        Ushuaia  -54.8000       278.15        56          75        4.63
# 2       Lüderitz  -26.6481       291.49        70           0        6.47
# 3      Zonguldak   41.2500       285.15        87          40        0.51
# 4          Seoul   37.5683       292.46        32           0        5.14
# ..           ...       ...          ...       ...         ...         ...
# 546   Eskilstuna   59.3666       276.03        48           0        5.14
# 547      Kasempa  -13.4584       294.29        59          16        3.58
# 548     Papetoai  -17.4961       299.98        65          20        1.54
# 549     Neturhāt   23.4833       308.57         7           1        4.50
# 550  Antofagasta  -23.6500       290.15        88           0        3.09
#
# [551 rows x 6 columns]

# %%
# function to convert 'Temperature' column from Kelvin to Farenheit
def Kelvin_to_Farenheit(kelvin):
    farenheit = (kelvin-273.15)*(9/5)+32
    return farenheit

# %%
weather_df['Temperature'] = Kelvin_to_Farenheit(weather_df['Temperature'])
weather_df
# Out:
#             City  Latitude  Temperature  Humidity  Cloudiness  Wind (MPH)
# 0    Yellowknife   62.4560       28.130        93          90        2.06
# 1        Ushuaia  -54.8000       41.000        56          75        4.63
# 2       Lüderitz  -26.6481       65.012        70           0        6.47
# 3      Zonguldak   41.2500       53.600        87          40        0.51
# 4          Seoul   37.5683       66.758        32           0        5.14
# ..           ...       ...          ...       ...         ...         ...
# 546   Eskilstuna   59.3666       37.184        48           0        5.14
# 547      Kasempa  -13.4584       70.052        59          16        3.58
# 548     Papetoai  -17.4961       80.294        65          20        1.54
# 549     Neturhāt   23.4833       95.756         7           1        4.50
# 550  Antofagasta  -23.6500       62.600        88           0        3.09
#
# [551 rows x 6 columns]

# %%
weather_df.dtypes
# Out:
# City            object
# Latitude       float64
# Temperature    float64
# Humidity         int64
# Cloudiness       int64
# Wind (MPH)     float64
# dtype: object

# %% [markdown]
# ##### Analysis of 'Temperature (Farenheit) v. Latitude'

# %%
# Scatter Plot - Temperature (Farenheit) v. Latitude
x_values = weather_df['Latitude']
y_values = weather_df['Temperature']
plt.scatter(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Temperature (Farenheit)')
plt.show()

# %% [markdown]
# ##### Analysis of 'Humidity (%) v. Latitude'

# %%
# Scatter Plot - Humidity (%) v. Latitude
x_values = weather_df['Latitude']
y_values = weather_df['Humidity']
plt.scatter(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.show()

# %% [markdown]
# ##### Analysis of 'Cloudiness(%) v. Latitude'

# %%
# Scatter Plot - Cloudiness (%) v. Latitude
x_values = weather_df['Latitude']
y_values = weather_df['Cloudiness']
plt.scatter(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.show()

# %% [markdown]
# ##### Analysis of  'Wind Speed (mph) v. Latitude'

# %%
# Scatter Plot - Wind Speed (mph)) v. Latitude
x_values = weather_df['Latitude']
y_values = weather_df['Wind (MPH)']
plt.scatter(x_values, y_values)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.show()

# %% [markdown]
# ### Linear Regressions: Northern Hemisphere v. Southern Hemisphere

# %%
# Northern Hemisphere Data Frame
northWeather_df = weather_df.loc[(
    weather_df['Latitude'] >= 0)]
northWeather_df
# Out:
#             City  Latitude  Temperature  Humidity  Cloudiness  Wind (MPH)
# 0    Yellowknife   62.4560       28.130        93          90        2.06
# 3      Zonguldak   41.2500       53.600        87          40        0.51
# 4          Seoul   37.5683       66.758        32           0        5.14
# 5         Gonder   12.6000       74.570        34          72        2.53
# 6      Richfield   44.8833       61.196        82          40        3.09
# ..           ...       ...          ...       ...         ...         ...
# 542        Kumul   42.8000       65.426        17           0        0.60
# 543      Napāsar   27.9667       97.772         8           4        2.85
# 544     Wheatley   51.7473       33.476        80          20        3.09
# 546   Eskilstuna   59.3666       37.184        48           0        5.14
# 549     Neturhāt   23.4833       95.756         7           1        4.50
#
# [377 rows x 6 columns]

# %%
# Southern Hemisphere Data Frame
southWeather_df = weather_df.loc[(
    weather_df['Latitude'] < 0)]
southWeather_df
# Out:
#             City  Latitude  Temperature  Humidity  Cloudiness  Wind (MPH)
# 1        Ushuaia  -54.8000       41.000        56          75        4.63
# 2       Lüderitz  -26.6481       65.012        70           0        6.47
# 8       Cidreira  -30.1811       71.942        83         100        5.55
# 10        Atuona   -9.8000       80.654        79          86        4.17
# 11      Souillac  -20.5167       82.400        74          40        5.66
# ..           ...       ...          ...       ...         ...         ...
# 533     Mahanoro  -19.9000       82.706        73           1        2.69
# 545     Santa Fe  -31.6333       66.434        96          68        0.89
# 547      Kasempa  -13.4584       70.052        59          16        3.58
# 548     Papetoai  -17.4961       80.294        65          20        1.54
# 550  Antofagasta  -23.6500       62.600        88           0        3.09
#
# [174 rows x 6 columns]

# %% [markdown]
# #### Temperature (Farenheit) Linear Regressions

# %%
# Linear Regression - Temperature (Farenheit) v. Latitude (Northern Hemisphere)
x_values = northWeather_df['Latitude']
y_values = northWeather_df['Temperature']
plt.scatter(x_values, y_values)
plt.title('Temperature Linear Regression - Northern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Temperature (Farenheit)')
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
plt.show()
print(f"The r-value is: {rvalue**2}")

# Linear Regression - Temperature (Farenheit) v. Latitude (Southern Hemisphere)
x_values = southWeather_df['Latitude']
y_values = southWeather_df['Temperature']
plt.scatter(x_values, y_values)
plt.title('Temperature Linear Regression - Southern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Temperature (Farenheit)')
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
plt.show()
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.7887272523548478
# The r-value is: 0.320727905436765

# %% [markdown]
# #### Humidity (%) Linear Regressions

# %%
# Linear Regression - Humidity (%) v. Latitude (Northern Hemisphere)
x_values = northWeather_df['Latitude']
y_values = northWeather_df['Humidity']
plt.scatter(x_values, y_values)
plt.title('Humidity Linear Regression - Northern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
plt.show()
print(f"The r-value is: {rvalue**2}")

# Linear Regression - Humidity (%) v. Latitude (Southern Hemisphere)
x_values = southWeather_df['Latitude']
y_values = southWeather_df['Humidity']
plt.scatter(x_values, y_values)
plt.title('Humidity Linear Regression - Southern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
plt.show()
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.0974124026200076
# The r-value is: 0.00941843834824139

# %% [markdown]
# #### Cloudiness (%) Linear Regression

# %%
# Linear Regression - Cloudiness (%) v. Latitude (Northern Hemisphere)
x_values = northWeather_df['Latitude']
y_values = northWeather_df['Cloudiness']
plt.scatter(x_values, y_values)
plt.title('Cloudiness Linear Regression - Northern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
plt.show()
print(f"The r-value is: {rvalue**2}")

# Linear Regression - Cloudiness (%) v. Latitude (Southern Hemisphere)
x_values = southWeather_df['Latitude']
y_values = southWeather_df['Cloudiness']
plt.scatter(x_values, y_values)
plt.title('Cloudiness Linear Regression - Southern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
plt.show()
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.07310811815645935
# The r-value is: 0.07614626026971498

# %% [markdown]
# #### Wind Speed (mph) Linear Regressions

# %%
# Linear Regression - Wind Speed (mph) v. Latitude (Northern Hemisphere)
x_values = northWeather_df['Latitude']
y_values = northWeather_df['Wind (MPH)']
plt.scatter(x_values, y_values)
plt.title('Wind Speed Linear Regression - Northern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
plt.show()
print(f"The r-value is: {rvalue**2}")

# Linear Regression - Wind Speed (mph) v. Latitude (Southern Hemisphere)
x_values = southWeather_df['Latitude']
y_values = southWeather_df['Wind (MPH)']
plt.scatter(x_values, y_values)
plt.title('Wind Speed Linear Regression - Southern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
plt.show()
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.01796877676399664
# The r-value is: 0.05496046765012013
