# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\nikoe\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\nikoe\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats

# Import API key
from config import weatherPy_apiKey

# Incorporated citipy to determine city based on latitude and longitude

from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
print(weatherPy_apiKey)
# Out:
# 54f6f5bb1a7c4610462289caa0693a66

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create an empty list to store JSON responses
response_json = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 635

# %%
# Build query URL
queryUrl = "http://api.openweathermap.org/data/2.5/weather?" + "appid=" + weatherPy_apiKey + "&q="

# %%
# creating dataframe wtih test_cities
test_cities = ['acapulco', 'jamestown', 'dali', 'malatya', 'manila', 'pevek', 'cidreira']
responses = []
city_name = []
latitude = []
temperature = []
humidity = []
clouds = []
wind = []


for city in cities:
    weather_data = requests.get(queryUrl + city).json()
    responses.append(weather_data)
    try:
        city_name.append(weather_data['name'])
        latitude.append(weather_data['coord']['lat'])
        temperature.append(weather_data['main']['temp'])
        humidity.append(weather_data['main']['humidity'])
        clouds.append(weather_data['clouds']['all'])
        wind.append(weather_data['wind']['speed'])
        print(f'{city} found')
    except:
        print(f'**{city} not found**')
        pass
# Out:
# beringovskiy found
# chuy found
# lebu found
# ushuaia found
# provideniya found
# iqaluit found
# hilo found
# fukue found
# rikitea found
# castro found
# surt found
# bluff found
# **umm durman not found**
# clyde river found
# sinnamary found
# mataura found
# luderitz found
# langarud found
# kidal found
# velsk found
# vaini found
# grindavik found
# yellowknife found
# severnoye found
# saskylakh found
# punta arenas found
# port alfred found
# lavrentiya found
# guerrero negro found
# jamestown found
# albany found
# busselton found
# nyagan found
# tuktoyaktuk found
# sao filipe found
# belaya kholunitsa found
# ilulissat found
# **amderma not found**
# tuatapere found
# yeppoon found
# diamantino found
# **taolanaro not found**
# arraial do cabo found
# **nizhneyansk not found**
# rio grande found
# mgandu found
# los aquijes found
# kavaratti found
# **karamay not found**
# bredasdorp found
# oranjestad found
# lake charles found
# haicheng found
# barrow found
# mar del plata found
# pandan found
# atuona found
# orange cove found
# bitung found
# terrace found
# dong hoi found
# dikson found
# hermanus found
# san cristobal found
# la ronge found
# voyvozh found
# henties bay found
# hobart found
# **barentsburg not found**
# **gurskoye not found**
# kichera found
# port lincoln found
# hovd found
# port-gentil found
# lima found
# port elizabeth found
# alice springs found
# asfi found
# busok found
# praia da vitoria found
# upernavik found
# mehamn found
# pevek found
# **louisbourg not found**
# grayvoron found
# zlitan found
# meadow lake found
# bucerias found
# ribeira grande found
# yurimaguas found
# **parras not found**
# puerto ayora found
# east london found
# khatanga found
# mount isa found
# portland found
# avera found
# butaritari found
# **mys shmidta not found**
# puerto escondido found
# bagotville found
# thompson found
# narsaq found
# **tumannyy not found**
# rocha found
# mahebourg found
# klaksvik found
# cape town found
# havre-saint-pierre found
# carnarvon found
# **belushya guba not found**
# karratha found
# kapaa found
# kodiak found
# pokhara found
# namibe found
# **lolua not found**
# san jose found
# suntar found
# vanimo found
# nowa deba found
# sobolevo found
# tignere found
# lorengau found
# soure found
# tura found
# new norfolk found
# bandarbeyla found
# buzmeyin found
# airai found
# touros found
# hithadhoo found
# macae found
# vyazma found
# chepen found
# vuktyl found
# itarema found
# saldanha found
# evensk found
# neepawa found
# porto walter found
# bengkulu found
# te anau found
# kharitonovo found
# salalah found
# lompoc found
# grootfontein found
# fugen found
# vardo found
# mogadishu found
# mount gambier found
# nanortalik found
# san pedro found
# uige found
# cuamba found
# baiyin found
# baykit found
# brumado found
# vaitape found
# bekhteyevka found
# kalangala found
# abu samrah found
# anadyr found
# verkhoyansk found
# **yefimovskiy not found**
# port hawkesbury found
# warsaw found
# mandalgovi found
# atar found
# north platte found
# gamba found
# wanning found
# beira found
# cayenne found
# sao miguel do araguaia found
# fallon found
# **ondorhaan not found**
# tumpat found
# paamiut found
# arusha found
# bilibino found
# charlestown found
# barranca found
# bhindar found
# mereni found
# dibulla found
# brockville found
# taunggyi found
# kasama found
# troitskoye found
# juneau found
# grants pass found
# vostok found
# **saleaula not found**
# vila velha found
# cancun found
# ballinrobe found
# **dien bien not found**
# **grand centre not found**
# san matias found

# %%
#print(responses)

# %%
weather_df = pd.DataFrame({
    'City': city_name,
    'Latitude': latitude,
    'Temperature': temperature,
    'Humidity': humidity,
    'Cloudiness': clouds,
    'Wind (MPH)': wind
})

weather_df
# Out:
#              City  Latitude  Temperature  Humidity  Cloudiness  Wind (MPH)
# 0    Beringovskiy   63.0500       255.69        83          10        3.59
# 1            Chui  -33.6971       292.76        88           8        3.36
# 2            Lebu  -37.6167       287.31        90         100        2.80
# 3         Ushuaia  -54.8000       283.15        71          75        2.06
# 4     Provideniya   64.3833       260.15        61           0        3.00
# ..            ...       ...          ...       ...         ...         ...
# 573        Vostok   46.4856       268.77        80          99        3.57
# 574    Vila Velha  -20.3297       298.15        78          20        2.57
# 575        Cancún   21.1743       298.85        69          90        4.63
# 576    Ballinrobe   53.6333       278.88         3          29        5.12
# 577    San Matías  -16.3667       299.71        70          81        1.17
#
# [578 rows x 6 columns]

# %%
# function to convert 'Temperature' column from Kelvin to Farenheit
def Kelvin_to_Farenheit(kelvin):
    farenheit = (kelvin-273.15)*(9/5)+32
    return farenheit

# %%
weather_df['Temperature'] = Kelvin_to_Farenheit(weather_df['Temperature'])
weather_df
# Out:
#              City  Latitude  Temperature  Humidity  Cloudiness  Wind (MPH)
# 0    Beringovskiy   63.0500        0.572        83          10        3.59
# 1            Chui  -33.6971       67.298        88           8        3.36
# 2            Lebu  -37.6167       57.488        90         100        2.80
# 3         Ushuaia  -54.8000       50.000        71          75        2.06
# 4     Provideniya   64.3833        8.600        61           0        3.00
# ..            ...       ...          ...       ...         ...         ...
# 573        Vostok   46.4856       24.116        80          99        3.57
# 574    Vila Velha  -20.3297       77.000        78          20        2.57
# 575        Cancún   21.1743       78.260        69          90        4.63
# 576    Ballinrobe   53.6333       42.314         3          29        5.12
# 577    San Matías  -16.3667       79.808        70          81        1.17
#
# [578 rows x 6 columns]

# %%
weather_df.dtypes
# Out:
# City            object
# Latitude       float64
# Temperature    float64
# Humidity         int64
# Cloudiness       int64
# Wind (MPH)     float64
# dtype: object

# %% [markdown]
# ##### Analysis of 'Temperature (Farenheit) v. Latitude'

# %%
# Scatter Plot - Temperature (Farenheit) v. Latitude
x_values = weather_df['Latitude']
y_values = weather_df['Temperature']
plt.scatter(x_values, y_values)
plt.title('Temperature v. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Temperature (Farenheit)')
plt.show()

# %% [markdown]
# ##### Analysis of 'Humidity (%) v. Latitude'

# %%
# Scatter Plot - Humidity (%) v. Latitude
x_values = weather_df['Latitude']
y_values = weather_df['Humidity']
plt.scatter(x_values, y_values)
plt.title('Humidity v. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.show()

# %% [markdown]
# ##### Analysis of 'Cloudiness(%) v. Latitude'

# %%
# Scatter Plot - Cloudiness (%) v. Latitude
x_values = weather_df['Latitude']
y_values = weather_df['Cloudiness']
plt.scatter(x_values, y_values)
plt.title('Cloudiness v. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.show()

# %% [markdown]
# ##### Analysis of  'Wind Speed (mph) v. Latitude'

# %%
# Scatter Plot - Wind Speed (mph)) v. Latitude
x_values = weather_df['Latitude']
y_values = weather_df['Wind (MPH)']
plt.scatter(x_values, y_values)
plt.title('Wind Speed v. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.show()

# %% [markdown]
# ### Linear Regressions: Northern Hemisphere v. Southern Hemisphere

# %%
# Northern Hemisphere Data Frame
northWeather_df = weather_df.loc[(
    weather_df['Latitude'] >= 0)]
northWeather_df
# Out:
#              City  Latitude  Temperature  Humidity  Cloudiness  Wind (MPH)
# 0    Beringovskiy   63.0500        0.572        83          10        3.59
# 4     Provideniya   64.3833        8.600        61           0        3.00
# 5         Iqaluit   63.7506       17.600        93          75        4.12
# 6            Hilo   19.7297       67.298        78          90        4.63
# 7        Fukuechō   32.6881       61.376        49          29        8.01
# ..            ...       ...          ...       ...         ...         ...
# 571        Juneau   58.3019       32.900        81          90        6.69
# 572   Grants Pass   42.4390       71.330        16           1        0.82
# 573        Vostok   46.4856       24.116        80          99        3.57
# 575        Cancún   21.1743       78.260        69          90        4.63
# 576    Ballinrobe   53.6333       42.314         3          29        5.12
#
# [391 rows x 6 columns]

# %%
# Southern Hemisphere Data Frame
southWeather_df = weather_df.loc[(
    weather_df['Latitude'] < 0)]
southWeather_df
# Out:
#             City  Latitude  Temperature  Humidity  Cloudiness  Wind (MPH)
# 1           Chui  -33.6971       67.298        88           8        3.36
# 2           Lebu  -37.6167       57.488        90         100        2.80
# 3        Ushuaia  -54.8000       50.000        71          75        2.06
# 8        Rikitea  -23.1203       77.288        70           9        3.97
# 9         Castro  -24.7911       59.198        94          49        2.08
# ..           ...       ...          ...       ...         ...         ...
# 562  Charlestown  -32.9500       71.474        97          22        0.45
# 563     Barranca  -10.7500       71.726        77          97        3.96
# 569       Kasama  -10.2129       60.296        97          33        2.80
# 574   Vila Velha  -20.3297       77.000        78          20        2.57
# 577   San Matías  -16.3667       79.808        70          81        1.17
#
# [187 rows x 6 columns]

# %% [markdown]
# #### Temperature (Farenheit) Linear Regressions

# %%
# Linear Regression - Temperature (Farenheit) v. Latitude (Northern Hemisphere)
x_values = northWeather_df['Latitude']
y_values = northWeather_df['Temperature']
plt.scatter(x_values, y_values)
plt.title('Temperature Linear Regression - Northern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Temperature (Farenheit)')
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
plt.show()
print(f"The r-value is: {rvalue**2}")

# Linear Regression - Temperature (Farenheit) v. Latitude (Southern Hemisphere)
x_values = southWeather_df['Latitude']
y_values = southWeather_df['Temperature']
plt.scatter(x_values, y_values)
plt.title('Temperature Linear Regression - Southern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Temperature (Farenheit)')
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
plt.show()
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.7850776118368773
# The r-value is: 0.4572952089606868

# %% [markdown]
# #### Humidity (%) Linear Regressions

# %%
# Linear Regression - Humidity (%) v. Latitude (Northern Hemisphere)
x_values = northWeather_df['Latitude']
y_values = northWeather_df['Humidity']
plt.scatter(x_values, y_values)
plt.title('Humidity Linear Regression - Northern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
plt.show()
print(f"The r-value is: {rvalue**2}")

# Linear Regression - Humidity (%) v. Latitude (Southern Hemisphere)
x_values = southWeather_df['Latitude']
y_values = southWeather_df['Humidity']
plt.scatter(x_values, y_values)
plt.title('Humidity Linear Regression - Southern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
plt.show()
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.024593164660002977
# The r-value is: 0.008793116387831701

# %% [markdown]
# #### Cloudiness (%) Linear Regression

# %%
# Linear Regression - Cloudiness (%) v. Latitude (Northern Hemisphere)
x_values = northWeather_df['Latitude']
y_values = northWeather_df['Cloudiness']
plt.scatter(x_values, y_values)
plt.title('Cloudiness Linear Regression - Northern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
plt.show()
print(f"The r-value is: {rvalue**2}")

# Linear Regression - Cloudiness (%) v. Latitude (Southern Hemisphere)
x_values = southWeather_df['Latitude']
y_values = southWeather_df['Cloudiness']
plt.scatter(x_values, y_values)
plt.title('Cloudiness Linear Regression - Southern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
plt.show()
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.021131455872997383
# The r-value is: 0.04259836935240925

# %% [markdown]
# #### Wind Speed (mph) Linear Regressions

# %%
# Linear Regression - Wind Speed (mph) v. Latitude (Northern Hemisphere)
x_values = northWeather_df['Latitude']
y_values = northWeather_df['Wind (MPH)']
plt.scatter(x_values, y_values)
plt.title('Wind Speed Linear Regression - Northern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
plt.show()
print(f"The r-value is: {rvalue**2}")

# Linear Regression - Wind Speed (mph) v. Latitude (Southern Hemisphere)
x_values = southWeather_df['Latitude']
y_values = southWeather_df['Wind (MPH)']
plt.scatter(x_values, y_values)
plt.title('Wind Speed Linear Regression - Southern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
plt.show()
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.011409697101988404
# The r-value is: 0.010935695767116746
