# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\nikoe\anaconda3\lib\site-packages (0.0.5)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: kdtree>=0.12 in c:\users\nikoe\anaconda3\lib\site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats
from pprint import pprint

# Import API key
from config import weatherPy_apiKey

# Incorporated citipy to determine city based on latitude and longitude

from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# Out:
# 54f6f5bb1a7c4610462289caa0693a66

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create an empty list to store JSON responses
response_json = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %%
# Build query URL
queryUrl = "http://api.openweathermap.org/data/2.5/weather?" + "appid=" + weatherPy_apiKey + "&q="

# %%
# creating dataframe wtih test_cities
test_cities = ['acapulco', 'jamestown', 'dali', 'malatya', 'manila', 'pevek', 'cidreira']
responses = []
city_name = []
country_name = []
latitude = []
longitude = []
temperature = []
humidity = []
clouds = []
wind = []

index = 1
for city in cities:
    weather_data = requests.get(queryUrl + city).json()
    responses.append(weather_data)
    try:
        city_name.append(weather_data['name'])
        country_name.append(weather_data['sys']['country'])
        latitude.append(weather_data['coord']['lat'])
        longitude.append(weather_data['coord']['lon'])
        temperature.append(weather_data['main']['temp'])
        humidity.append(weather_data['main']['humidity'])
        clouds.append(weather_data['clouds']['all'])
        wind.append(weather_data['wind']['speed'])
        print(f'Record {index} | {city} found')
        index += 1
    except:
        print(f'Record {index} | **{city} not found**')
        index += 1
        pass
# Out:
# Record 1 | vaini found
# Record 2 | tasiilaq found
# Record 3 | itarema found
# Record 4 | hobart found
# Record 5 | rikitea found
# Record 6 | el alto found
# Record 7 | victoria found
# Record 8 | atuona found
# Record 9 | khatanga found
# Record 10 | **mys shmidta not found**
# Record 11 | mataura found
# Record 12 | chokurdakh found
# Record 13 | **taolanaro not found**
# Record 14 | bethel found
# Record 15 | bukama found
# Record 16 | cabo san lucas found
# Record 17 | deputatskiy found
# Record 18 | puerto ayora found
# Record 19 | busselton found
# Record 20 | hilo found
# Record 21 | punta arenas found
# Record 22 | bubaque found
# Record 23 | new norfolk found
# Record 24 | ushuaia found
# Record 25 | beisfjord found
# Record 26 | vanimo found
# Record 27 | barrow found
# Record 28 | oistins found
# Record 29 | bredasdorp found
# Record 30 | qaanaaq found
# Record 31 | zyryanka found
# Record 32 | tuatapere found
# Record 33 | lac du bonnet found
# Record 34 | auki found
# Record 35 | souillac found
# Record 36 | hithadhoo found
# Record 37 | los llanos de aridane found
# Record 38 | avarua found
# Record 39 | zhigansk found
# Record 40 | lagoa found
# Record 41 | yulara found
# Record 42 | iqaluit found
# Record 43 | bambous virieux found
# Record 44 | kapaa found
# Record 45 | santa isabel found
# Record 46 | baruun-urt found
# Record 47 | dikson found
# Record 48 | mihail kogalniceanu found
# Record 49 | san patricio found
# Record 50 | torbay found
# Record 51 | talara found
# Record 52 | varnavino found
# Record 53 | **tumannyy not found**
# Record 54 | portland found
# Record 55 | tiksi found
# Record 56 | **ust-kamchatsk not found**
# Record 57 | beruwala found
# Record 58 | hermanus found
# Record 59 | kaduqli found
# Record 60 | upernavik found
# Record 61 | nome found
# Record 62 | arraial do cabo found
# Record 63 | kautokeino found
# Record 64 | bluff found
# Record 65 | garissa found
# Record 66 | **belushya guba not found**
# Record 67 | bauchi found
# Record 68 | lebu found
# Record 69 | constitucion found
# Record 70 | **palabuhanratu not found**
# Record 71 | inta found
# Record 72 | te anau found
# Record 73 | chuy found
# Record 74 | bambanglipuro found
# Record 75 | jamestown found
# Record 76 | awjilah found
# Record 77 | talcahuano found
# Record 78 | pevek found
# Record 79 | kisangani found
# Record 80 | albany found
# Record 81 | port alfred found
# Record 82 | isangel found
# Record 83 | cape town found
# Record 84 | panji found
# Record 85 | grand gaube found
# Record 86 | husavik found
# Record 87 | nogales found
# Record 88 | **cirpan not found**
# Record 89 | pemangkat found
# Record 90 | aklavik found
# Record 91 | mount gambier found
# Record 92 | kinablangan found
# Record 93 | batagay found
# Record 94 | rawah found
# Record 95 | faanui found
# Record 96 | georgetown found
# Record 97 | mar del plata found
# Record 98 | oktyabrskoye found
# Record 99 | lisakovsk found
# Record 100 | dawei found
# Record 101 | hasaki found
# Record 102 | butaritari found
# Record 103 | novikovo found
# Record 104 | nikolskoye found
# Record 105 | **nizhneyansk not found**
# Record 106 | kijang found
# Record 107 | concarneau found
# Record 108 | qasigiannguit found
# Record 109 | cherskiy found
# Record 110 | saint-philippe found
# Record 111 | cairns found
# Record 112 | mosquera found
# Record 113 | havoysund found
# Record 114 | waterloo found
# Record 115 | nevsehir found
# Record 116 | **amderma not found**
# Record 117 | charters towers found
# Record 118 | provideniya found
# Record 119 | tara found
# Record 120 | **illoqqortoormiut not found**
# Record 121 | ola found
# Record 122 | general pico found
# Record 123 | ponta do sol found
# Record 124 | buraydah found
# Record 125 | tshikapa found
# Record 126 | boende found
# Record 127 | vila found
# Record 128 | yellowknife found
# Record 129 | leningradskiy found
# Record 130 | poya found
# Record 131 | luderitz found
# Record 132 | **kamenskoye not found**
# Record 133 | nouadhibou found
# Record 134 | marand found
# Record 135 | fortuna found
# Record 136 | guerrero negro found
# Record 137 | ahipara found
# Record 138 | touros found
# Record 139 | flin flon found
# Record 140 | saint george found
# Record 141 | havre-saint-pierre found
# Record 142 | fare found
# Record 143 | sarreguemines found
# Record 144 | carnarvon found
# Record 145 | mbekenyera found
# Record 146 | norman wells found
# Record 147 | mao found
# Record 148 | pangnirtung found
# Record 149 | saskylakh found
# Record 150 | sevierville found
# Record 151 | mayor pablo lagerenza found
# Record 152 | santa marta found
# Record 153 | **yeletskiy not found**
# Record 154 | dunedin found
# Record 155 | sao filipe found
# Record 156 | karratha found
# Record 157 | cockburn town found
# Record 158 | lasa found
# Record 159 | atar found
# Record 160 | kodiak found
# Record 161 | udala found
# Record 162 | wiwili found
# Record 163 | mafeteng found
# Record 164 | petropavlovsk-kamchatskiy found
# Record 165 | arvika found
# Record 166 | **skagastrond not found**
# Record 167 | marsa matruh found
# Record 168 | **deh rawud not found**
# Record 169 | wangkui found
# Record 170 | **attawapiskat not found**
# Record 171 | pontianak found
# Record 172 | sitka found
# Record 173 | varhaug found
# Record 174 | ulladulla found
# Record 175 | mahebourg found
# Record 176 | **barentsburg not found**
# Record 177 | airai found
# Record 178 | longyearbyen found
# Record 179 | hovd found
# Record 180 | sept-iles found
# Record 181 | vagur found
# Record 182 | turukhansk found
# Record 183 | thompson found
# Record 184 | camalu found
# Record 185 | pacific grove found
# Record 186 | **samusu not found**
# Record 187 | coos bay found
# Record 188 | stonewall found
# Record 189 | qui nhon found
# Record 190 | **tsihombe not found**
# Record 191 | mounana found
# Record 192 | mirnyy found
# Record 193 | puerto del rosario found
# Record 194 | henties bay found
# Record 195 | port augusta found
# Record 196 | pisco found
# Record 197 | baiyin found
# Record 198 | balkanabat found
# Record 199 | calabar found
# Record 200 | ribeira grande found
# Record 201 | dhidhdhoo found
# Record 202 | pimenta bueno found
# Record 203 | toora-khem found
# Record 204 | pedernales found
# Record 205 | lianyuan found
# Record 206 | port elizabeth found
# Record 207 | **grand river south east not found**
# Record 208 | hopkinsville found
# Record 209 | kaeo found
# Record 210 | lompoc found
# Record 211 | sarankhola found
# Record 212 | fayaoue found
# Record 213 | katsuura found
# Record 214 | alofi found
# Record 215 | bodden town found
# Record 216 | narsaq found
# Record 217 | nelson bay found
# Record 218 | visakhapatnam found
# Record 219 | juazeiro do norte found
# Record 220 | sao joao da barra found
# Record 221 | pakxan found
# Record 222 | gushikawa found
# Record 223 | walvis bay found
# Record 224 | polignano a mare found
# Record 225 | villavicencio found
# Record 226 | cayenne found
# Record 227 | tabou found
# Record 228 | belyy yar found
# Record 229 | muli found
# Record 230 | **maloshuyka not found**
# Record 231 | bengkulu found
# Record 232 | kollam found
# Record 233 | iquitos found
# Record 234 | broome found
# Record 235 | manoel urbano found
# Record 236 | porto novo found
# Record 237 | richards bay found
# Record 238 | geraldton found
# Record 239 | rayevskiy found
# Record 240 | neepawa found
# Record 241 | merauke found
# Record 242 | ilulissat found
# Record 243 | beringovskiy found
# Record 244 | ishigaki found
# Record 245 | kavieng found
# Record 246 | **daxian not found**
# Record 247 | shahr-e babak found
# Record 248 | luganville found
# Record 249 | **louisbourg not found**
# Record 250 | muros found
# Record 251 | **tabarqah not found**
# Record 252 | ilhabela found
# Record 253 | mount isa found
# Record 254 | verkhnevilyuysk found
# Record 255 | poum found
# Record 256 | alakurtti found
# Record 257 | ajdabiya found
# Record 258 | **barroualie not found**
# Record 259 | panorama found
# Record 260 | mortka found
# Record 261 | ambanja found
# Record 262 | olafsvik found
# Record 263 | **duz not found**
# Record 264 | comodoro rivadavia found
# Record 265 | srednekolymsk found
# Record 266 | kent found
# Record 267 | kirakira found
# Record 268 | minot found
# Record 269 | dembi dolo found
# Record 270 | salalah found
# Record 271 | kaifeng found
# Record 272 | pacifica found
# Record 273 | moron found
# Record 274 | nago found
# Record 275 | **sidi bu zayd not found**
# Record 276 | derzhavinsk found
# Record 277 | **umzimvubu not found**
# Record 278 | mombaca found
# Record 279 | kuminskiy found
# Record 280 | taybad found
# Record 281 | komsomolskiy found
# Record 282 | **vaitupu not found**
# Record 283 | hinckley found
# Record 284 | karangasem found
# Record 285 | huarmey found
# Record 286 | houston found
# Record 287 | toktogul found
# Record 288 | artigas found
# Record 289 | **karauzyak not found**
# Record 290 | urucara found
# Record 291 | russell found
# Record 292 | camacha found
# Record 293 | maarianhamina found
# Record 294 | troyes found
# Record 295 | montepuez found
# Record 296 | maniitsoq found
# Record 297 | port-gentil found
# Record 298 | marechal deodoro found
# Record 299 | **cam pha not found**
# Record 300 | glazov found
# Record 301 | kuusamo found
# Record 302 | gat found
# Record 303 | shuangyang found
# Record 304 | visby found
# Record 305 | yar-sale found
# Record 306 | mindelo found
# Record 307 | reo found
# Record 308 | **kawana waters not found**
# Record 309 | **geresk not found**
# Record 310 | ostrovnoy found
# Record 311 | **saleaula not found**
# Record 312 | kassala found
# Record 313 | madang found
# Record 314 | bathsheba found
# Record 315 | inhambane found
# Record 316 | belmonte found
# Record 317 | slave lake found
# Record 318 | ancud found
# Record 319 | dakar found
# Record 320 | santa cruz cabralia found
# Record 321 | priargunsk found
# Record 322 | les cayes found
# Record 323 | rawson found
# Record 324 | chicama found
# Record 325 | debno found
# Record 326 | oranjestad found
# Record 327 | honiara found
# Record 328 | shenzhen found
# Record 329 | makakilo city found
# Record 330 | omboue found
# Record 331 | vestmanna found
# Record 332 | limoeiro do ajuru found
# Record 333 | kenai found
# Record 334 | castro found
# Record 335 | kloulklubed found
# Record 336 | dzhebariki-khaya found
# Record 337 | nikki found
# Record 338 | grindavik found
# Record 339 | **ndouci not found**
# Record 340 | lena found
# Record 341 | cidreira found
# Record 342 | severo-kurilsk found
# Record 343 | ovruch found
# Record 344 | zheleznogorsk-ilimskiy found
# Record 345 | lopandino found
# Record 346 | sawakin found
# Record 347 | fairmont found
# Record 348 | qaqortoq found
# Record 349 | konya found
# Record 350 | san diego found
# Record 351 | areosa found
# Record 352 | kieta found
# Record 353 | bilokurakyne found
# Record 354 | lorengau found
# Record 355 | kahului found
# Record 356 | sassandra found
# Record 357 | fort nelson found
# Record 358 | hailar found
# Record 359 | surovikino found
# Record 360 | **solovetskiy not found**
# Record 361 | riyadh found
# Record 362 | wenling found
# Record 363 | tuktoyaktuk found
# Record 364 | **othonoi not found**
# Record 365 | **zachagansk not found**
# Record 366 | vardo found
# Record 367 | damietta found
# Record 368 | matiguas found
# Record 369 | vila franca do campo found
# Record 370 | kurilsk found
# Record 371 | agadez found
# Record 372 | ust-kulom found
# Record 373 | codrington found
# Record 374 | galesong found
# Record 375 | lishui found
# Record 376 | sterling found
# Record 377 | east london found
# Record 378 | pong found
# Record 379 | pastos bons found
# Record 380 | salinopolis found
# Record 381 | katherine found
# Record 382 | **tasbuget not found**
# Record 383 | warrington found
# Record 384 | kisesa found
# Record 385 | kaitangata found
# Record 386 | arman found
# Record 387 | kaseda found
# Record 388 | hadejia found
# Record 389 | **labutta not found**
# Record 390 | ussel found
# Record 391 | maralal found
# Record 392 | **lolua not found**
# Record 393 | kailua found
# Record 394 | lavrentiya found
# Record 395 | vilyuysk found
# Record 396 | novochernorechenskiy found
# Record 397 | port moresby found
# Record 398 | khandbari found
# Record 399 | belize found
# Record 400 | lukulu found
# Record 401 | tequila found
# Record 402 | benguela found
# Record 403 | meulaboh found
# Record 404 | talnakh found
# Record 405 | saldanha found
# Record 406 | novyy urengoy found
# Record 407 | canutama found
# Record 408 | bozeman found
# Record 409 | dargaville found
# Record 410 | divinopolis found
# Record 411 | korla found
# Record 412 | margate found
# Record 413 | hamilton found
# Record 414 | freeport found
# Record 415 | quelimane found
# Record 416 | saint-pierre found
# Record 417 | solsona found
# Record 418 | annigeri found
# Record 419 | kiama found
# Record 420 | uray found
# Record 421 | rosarito found
# Record 422 | maceio found
# Record 423 | **rungata not found**
# Record 424 | marquette found
# Record 425 | rio grande found
# Record 426 | colinas found
# Record 427 | pemberton found
# Record 428 | magistralnyy found
# Record 429 | charlestown found
# Record 430 | monrovia found
# Record 431 | barbate found
# Record 432 | segamat found
# Record 433 | san cristobal found
# Record 434 | dondo found
# Record 435 | coquimbo found
# Record 436 | yenagoa found
# Record 437 | bandarbeyla found
# Record 438 | lata found
# Record 439 | sakakah found
# Record 440 | mehamn found
# Record 441 | hofn found
# Record 442 | puerto narino found
# Record 443 | thunder bay found
# Record 444 | tazmalt found
# Record 445 | kidal found
# Record 446 | tutoia found
# Record 447 | ambovombe found
# Record 448 | muravlenko found
# Record 449 | kruisfontein found
# Record 450 | teya found
# Record 451 | bireun found
# Record 452 | callaguip found
# Record 453 | placido de castro found
# Record 454 | manono found
# Record 455 | naryan-mar found
# Record 456 | horasan found
# Record 457 | puerto madryn found
# Record 458 | berlevag found
# Record 459 | oktyabrskiy found
# Record 460 | yzeure found
# Record 461 | **ruatoria not found**
# Record 462 | **marcona not found**
# Record 463 | tsabong found
# Record 464 | san alberto found
# Record 465 | muisne found
# Record 466 | fallon found
# Record 467 | novobessergenevka found
# Record 468 | homer found
# Record 469 | **viligili not found**
# Record 470 | **phan rang not found**
# Record 471 | inirida found
# Record 472 | mecca found
# Record 473 | tazovskiy found
# Record 474 | wagar found
# Record 475 | **khormuj not found**
# Record 476 | **burica not found**
# Record 477 | bilibino found
# Record 478 | verkhnyaya toyma found
# Record 479 | **zolotinka not found**
# Record 480 | omsukchan found
# Record 481 | yerbogachen found
# Record 482 | chapais found
# Record 483 | nuevo casas grandes found
# Record 484 | tuy hoa found
# Record 485 | williston found
# Record 486 | marmaris found
# Record 487 | la ronge found
# Record 488 | canon city found
# Record 489 | utete found
# Record 490 | lobau found
# Record 491 | tessalit found
# Record 492 | namatanai found
# Record 493 | puro found
# Record 494 | labrea found
# Record 495 | hualmay found
# Record 496 | badou found
# Record 497 | guymon found
# Record 498 | adrar found
# Record 499 | noumea found
# Record 500 | carutapera found
# Record 501 | roald found
# Record 502 | solwezi found
# Record 503 | saint anthony found
# Record 504 | **rawannawi not found**
# Record 505 | mayo found
# Record 506 | acapulco found
# Record 507 | faya found
# Record 508 | mendota found
# Record 509 | bintulu found
# Record 510 | vila velha found
# Record 511 | urucui found
# Record 512 | catamarca found
# Record 513 | ahuimanu found
# Record 514 | kandiari found
# Record 515 | **fevralsk not found**
# Record 516 | ozernovskiy found
# Record 517 | sucua found
# Record 518 | kendari found
# Record 519 | ayaviri found
# Record 520 | avera found
# Record 521 | radhanpur found
# Record 522 | sechura found
# Record 523 | sibolga found
# Record 524 | barcelona found
# Record 525 | ladwa found
# Record 526 | betioky found
# Record 527 | esperance found
# Record 528 | maun found
# Record 529 | marawi found
# Record 530 | santa maria found
# Record 531 | sicamous found
# Record 532 | blytheville found
# Record 533 | xining found
# Record 534 | lowestoft found
# Record 535 | shingu found
# Record 536 | namibe found
# Record 537 | trang found
# Record 538 | pionerskiy found
# Record 539 | klaksvik found
# Record 540 | **karamea not found**
# Record 541 | nansio found
# Record 542 | opuwo found
# Record 543 | pokrovsk found
# Record 544 | paamiut found
# Record 545 | killybegs found
# Record 546 | breytovo found
# Record 547 | port macquarie found
# Record 548 | tura found
# Record 549 | manado found
# Record 550 | murino found
# Record 551 | the pas found
# Record 552 | lamar found
# Record 553 | reconquista found
# Record 554 | fez found
# Record 555 | abu samrah found
# Record 556 | belogorsk found
# Record 557 | ostersund found
# Record 558 | ushtobe found
# Record 559 | yumen found
# Record 560 | morro bay found
# Record 561 | buala found
# Record 562 | batemans bay found
# Record 563 | grand-santi found
# Record 564 | sulangan found
# Record 565 | **armacao dos buzios not found**
# Record 566 | tombouctou found
# Record 567 | thanh hoa found
# Record 568 | kondinskoye found
# Record 569 | ngara found
# Record 570 | kayerkan found
# Record 571 | guanica found
# Record 572 | nuuk found
# Record 573 | samaro found
# Record 574 | monterey found
# Record 575 | havre found
# Record 576 | fairbanks found
# Record 577 | banjar found
# Record 578 | port hedland found
# Record 579 | povenets found
# Record 580 | ati found
# Record 581 | svetlogorsk found
# Record 582 | puerto madero found
# Record 583 | leh found
# Record 584 | praia da vitoria found
# Record 585 | bugene found
# Record 586 | booue found
# Record 587 | mwense found
# Record 588 | hambantota found
# Record 589 | vilhena found
# Record 590 | chancay found
# Record 591 | naze found
# Record 592 | marsh harbour found
# Record 593 | china found
# Record 594 | temirtau found
# Record 595 | zhuhai found
# Record 596 | bratsk found
# Record 597 | san andres found
# Record 598 | troitskoye found
# Record 599 | vao found
# Record 600 | pafos found
# Record 601 | morlaix found
# Record 602 | asau found
# Record 603 | taksimo found
# Record 604 | **sedelnikovo not found**
# Record 605 | gambo found
# Record 606 | sola found
# Record 607 | inuvik found

# %%
pprint(responses)
# Out:
# [{'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': -21.2, 'lon': -175.2},
#   'dt': 1617907411,
#   'id': 4032243,
#   'main': {'feels_like': 294.76,
#            'humidity': 94,
#            'pressure': 1012,
#            'temp': 294.15,
#            'temp_max': 294.15,
#            'temp_min': 294.15},
#   'name': 'Vaini',
#   'sys': {'country': 'TO',
#           'id': 7285,
#           'sunrise': 1617990638,
#           'sunset': 1618032802,
#           'type': 1},
#   'timezone': 46800,
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 230, 'speed': 1.54}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 65.6145, 'lon': -37.6368},
#   'dt': 1617907358,
#   'id': 3424607,
#   'main': {'feels_like': 263.62,
#            'humidity': 68,
#            'pressure': 1029,
#            'temp': 267.15,
#            'temp_max': 267.15,
#            'temp_min': 267.15},
#   'name': 'Tasiilaq',
#   'sys': {'country': 'GL',
#           'id': 81,
#           'sunrise': 1617866266,
#           'sunset': 1617918388,
#           'type': 1},
#   'timezone': -7200,
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02d',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 210, 'speed': 2.06}},
#  {'base': 'stations',
#   'clouds': {'all': 91},
#   'cod': 200,
#   'coord': {'lat': -2.9248, 'lon': -39.9167},
#   'dt': 1617907412,
#   'id': 3393692,
#   'main': {'feels_like': 305.45,
#            'grnd_level': 1007,
#            'humidity': 74,
#            'pressure': 1009,
#            'sea_level': 1009,
#            'temp': 301.64,
#            'temp_max': 301.64,
#            'temp_min': 301.64},
#   'name': 'Itarema',
#   'sys': {'country': 'BR', 'sunrise': 1617871164, 'sunset': 1617914585},
#   'timezone': -10800,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 96, 'gust': 11.3, 'speed': 7.61}},
#  {'base': 'stations',
#   'clouds': {'all': 8},
#   'cod': 200,
#   'coord': {'lat': -42.8794, 'lon': 147.3294},
#   'dt': 1617907210,
#   'id': 2163355,
#   'main': {'feels_like': 282.53,
#            'humidity': 71,
#            'pressure': 998,
#            'temp': 283.58,
#            'temp_max': 284.26,
#            'temp_min': 282.04},
#   'name': 'Hobart',
#   'sys': {'country': 'AU',
#           'id': 9545,
#           'sunrise': 1617914137,
#           'sunset': 1617954518,
#           'type': 1},
#   'timezone': 36000,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 310, 'speed': 4.12}},
#  {'base': 'stations',
#   'clouds': {'all': 27},
#   'cod': 200,
#   'coord': {'lat': -23.1203, 'lon': -134.9692},
#   'dt': 1617907412,
#   'id': 4030556,
#   'main': {'feels_like': 297.91,
#            'grnd_level': 1013,
#            'humidity': 65,
#            'pressure': 1016,
#            'sea_level': 1016,
#            'temp': 297.7,
#            'temp_max': 297.7,
#            'temp_min': 297.7},
#   'name': 'Rikitea',
#   'sys': {'country': 'PF', 'sunrise': 1617894629, 'sunset': 1617936736},
#   'timezone': -32400,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 25, 'gust': 0.94, 'speed': 1.05}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -4.2714, 'lon': -81.2147},
#   'dt': 1617907412,
#   'id': 3697441,
#   'main': {'feels_like': 309.16,
#            'humidity': 49,
#            'pressure': 1009,
#            'temp': 306.15,
#            'temp_max': 306.15,
#            'temp_min': 306.15},
#   'name': 'El Alto',
#   'sys': {'country': 'PE',
#           'id': 8685,
#           'sunrise': 1617881115,
#           'sunset': 1617924453,
#           'type': 1},
#   'timezone': -18000,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 180, 'speed': 6.17}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 22.2855, 'lon': 114.1577},
#   'dt': 1617907171,
#   'id': 1819729,
#   'main': {'feels_like': 292.95,
#            'humidity': 83,
#            'pressure': 1014,
#            'temp': 292.77,
#            'temp_max': 294.82,
#            'temp_min': 288.15},
#   'name': 'Hong Kong',
#   'rain': {'1h': 0.65},
#   'sys': {'country': 'HK',
#           'id': 2035800,
#           'sunrise': 1617919724,
#           'sunset': 1617964851,
#           'type': 3},
#   'timezone': 28800,
#   'visibility': 10000,
#   'weather': [{'description': 'light rain',
#                'icon': '10n',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 24, 'gust': 3.58, 'speed': 0.89}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -9.8, 'lon': -139.0333},
#   'dt': 1617907413,
#   'id': 4020109,
#   'main': {'feels_like': 302.63,
#            'grnd_level': 1005,
#            'humidity': 75,
#            'pressure': 1013,
#            'sea_level': 1013,
#            'temp': 300.25,
#            'temp_max': 300.25,
#            'temp_min': 300.25},
#   'name': 'Atuona',
#   'sys': {'country': 'PF', 'sunrise': 1617895164, 'sunset': 1617938152},
#   'timezone': -34200,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 93, 'gust': 7.85, 'speed': 7.26}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 71.9667, 'lon': 102.5},
#   'dt': 1617907413,
#   'id': 2022572,
#   'main': {'feels_like': 241.65,
#            'grnd_level': 1036,
#            'humidity': 100,
#            'pressure': 1040,
#            'sea_level': 1040,
#            'temp': 241.65,
#            'temp_max': 241.65,
#            'temp_min': 241.65},
#   'name': 'Khatanga',
#   'sys': {'country': 'RU', 'sunrise': 1617917001, 'sunset': 1617973168},
#   'timezone': 25200,
#   'visibility': 4085,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 67, 'gust': 1.14, 'speed': 1.18}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -46.1927, 'lon': 168.8643},
#   'dt': 1617907414,
#   'id': 6201424,
#   'main': {'feels_like': 277.59,
#            'humidity': 95,
#            'pressure': 1012,
#            'temp': 277.59,
#            'temp_max': 277.59,
#            'temp_min': 277.59},
#   'name': 'Mataura',
#   'sys': {'country': 'NZ',
#           'id': 2008959,
#           'sunrise': 1617909155,
#           'sunset': 1617949165,
#           'type': 3},
#   'timezone': 43200,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 20, 'gust': 1.34, 'speed': 0.45}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 70.6333, 'lon': 147.9167},
#   'dt': 1617907414,
#   'id': 2126123,
#   'main': {'feels_like': 241.89,
#            'grnd_level': 1028,
#            'humidity': 95,
#            'pressure': 1032,
#            'sea_level': 1032,
#            'temp': 248.67,
#            'temp_max': 248.67,
#            'temp_min': 248.67},
#   'name': 'Chokurdakh',
#   'sys': {'country': 'RU', 'sunrise': 1617906647, 'sunset': 1617961726},
#   'timezone': 39600,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 46, 'gust': 2.39, 'speed': 2.13}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 1},
#   'cod': 200,
#   'coord': {'lat': 41.3712, 'lon': -73.414},
#   'dt': 1617907162,
#   'id': 5282297,
#   'main': {'feels_like': 293.57,
#            'humidity': 37,
#            'pressure': 1018,
#            'temp': 294.42,
#            'temp_max': 295.37,
#            'temp_min': 293.71},
#   'name': 'Bethel',
#   'sys': {'country': 'US',
#           'id': 3888,
#           'sunrise': 1617877476,
#           'sunset': 1617924349,
#           'type': 1},
#   'timezone': -14400,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 60, 'speed': 3.09}},
#  {'base': 'stations',
#   'clouds': {'all': 26},
#   'cod': 200,
#   'coord': {'lat': -9.2, 'lon': 25.85},
#   'dt': 1617907415,
#   'id': 217834,
#   'main': {'feels_like': 294.24,
#            'grnd_level': 946,
#            'humidity': 95,
#            'pressure': 1013,
#            'sea_level': 1013,
#            'temp': 293.65,
#            'temp_max': 293.65,
#            'temp_min': 293.65},
#   'name': 'Bukama',
#   'sys': {'country': 'CD', 'sunrise': 1617855574, 'sunset': 1617898614},
#   'timezone': 7200,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 216, 'gust': 1.21, 'speed': 1.13}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 22.8909, 'lon': -109.9124},
#   'dt': 1617907202,
#   'id': 3985710,
#   'main': {'feels_like': 302.7,
#            'humidity': 47,
#            'pressure': 1015,
#            'temp': 302.35,
#            'temp_max': 306.15,
#            'temp_min': 299.15},
#   'name': 'Cabo San Lucas',
#   'sys': {'country': 'MX',
#           'id': 7151,
#           'sunrise': 1617887098,
#           'sunset': 1617932243,
#           'type': 1},
#   'timezone': -21600,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 200, 'speed': 3.6}},
#  {'base': 'stations',
#   'clouds': {'all': 82},
#   'cod': 200,
#   'coord': {'lat': 69.3, 'lon': 139.9},
#   'dt': 1617907416,
#   'id': 2028164,
#   'main': {'feels_like': 244.22,
#            'grnd_level': 954,
#            'humidity': 99,
#            'pressure': 1033,
#            'sea_level': 1033,
#            'temp': 244.22,
#            'temp_max': 244.22,
#            'temp_min': 244.22},
#   'name': 'Deputatsky',
#   'sys': {'country': 'RU', 'sunrise': 1617908999, 'sunset': 1617963222},
#   'timezone': 36000,
#   'visibility': 7934,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 257, 'gust': 1.18, 'speed': 1.25}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': -0.7393, 'lon': -90.3518},
#   'dt': 1617907416,
#   'id': 3652764,
#   'main': {'feels_like': 305.08,
#            'humidity': 66,
#            'pressure': 1011,
#            'temp': 302.11,
#            'temp_max': 303.15,
#            'temp_min': 301.48},
#   'name': 'Puerto Ayora',
#   'sys': {'country': 'EC',
#           'id': 8521,
#           'sunrise': 1617883199,
#           'sunset': 1617926755,
#           'type': 1},
#   'timezone': -21600,
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02d',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 120, 'speed': 6.17}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -33.65, 'lon': 115.3333},
#   'dt': 1617907417,
#   'id': 2075265,
#   'main': {'feels_like': 278.63,
#            'humidity': 90,
#            'pressure': 1022,
#            'temp': 281.89,
#            'temp_max': 282.59,
#            'temp_min': 281.48},
#   'name': 'Busselton',
#   'sys': {'country': 'AU',
#           'id': 2008303,
#           'sunrise': 1617921375,
#           'sunset': 1617962635,
#           'type': 3},
#   'timezone': 28800,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 143, 'gust': 12.98, 'speed': 6.5}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 19.7297, 'lon': -155.09},
#   'dt': 1617907381,
#   'id': 5855927,
#   'main': {'feels_like': 293.4,
#            'humidity': 68,
#            'pressure': 1020,
#            'temp': 293.53,
#            'temp_max': 296.15,
#            'temp_min': 290.37},
#   'name': 'Hilo',
#   'rain': {'1h': 1.02},
#   'sys': {'country': 'US',
#           'id': 7881,
#           'sunrise': 1617898053,
#           'sunset': 1617942969,
#           'type': 1},
#   'timezone': -36000,
#   'visibility': 10000,
#   'weather': [{'description': 'moderate rain',
#                'icon': '10d',
#                'id': 501,
#                'main': 'Rain'}],
#   'wind': {'deg': 60, 'speed': 4.12}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -53.15, 'lon': -70.9167},
#   'dt': 1617907320,
#   'id': 3874787,
#   'main': {'feels_like': 279,
#            'humidity': 53,
#            'pressure': 1007,
#            'temp': 283.15,
#            'temp_max': 283.15,
#            'temp_min': 283.15},
#   'name': 'Punta Arenas',
#   'sys': {'country': 'CL',
#           'id': 8487,
#           'sunrise': 1617880754,
#           'sunset': 1617919873,
#           'type': 1},
#   'timezone': -10800,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 260, 'speed': 11.83}},
#  {'base': 'stations',
#   'clouds': {'all': 14},
#   'cod': 200,
#   'coord': {'lat': 11.2833, 'lon': -15.8333},
#   'dt': 1617907417,
#   'id': 2374583,
#   'main': {'feels_like': 298.76,
#            'grnd_level': 1006,
#            'humidity': 74,
#            'pressure': 1009,
#            'sea_level': 1009,
#            'temp': 298.26,
#            'temp_max': 298.26,
#            'temp_min': 298.26},
#   'name': 'Bubaque',
#   'sys': {'country': 'GW', 'sunrise': 1617864939, 'sunset': 1617909252},
#   'timezone': 0,
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02d',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 227, 'gust': 8.95, 'speed': 8.49}},
#  {'base': 'stations',
#   'clouds': {'all': 15},
#   'cod': 200,
#   'coord': {'lat': -42.7826, 'lon': 147.0587},
#   'dt': 1617907418,
#   'id': 2155415,
#   'main': {'feels_like': 282.77,
#            'humidity': 63,
#            'pressure': 998,
#            'temp': 282.77,
#            'temp_max': 284.26,
#            'temp_min': 280.93},
#   'name': 'New Norfolk',
#   'sys': {'country': 'AU',
#           'id': 2031307,
#           'sunrise': 1617914197,
#           'sunset': 1617954588,
#           'type': 3},
#   'timezone': 36000,
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 250, 'gust': 2.68, 'speed': 0.89}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': -54.8, 'lon': -68.3},
#   'dt': 1617907141,
#   'id': 3833367,
#   'main': {'feels_like': 274.66,
#            'humidity': 76,
#            'pressure': 1002,
#            'temp': 280.15,
#            'temp_max': 280.15,
#            'temp_min': 280.15},
#   'name': 'Ushuaia',
#   'sys': {'country': 'AR',
#           'id': 8303,
#           'sunrise': 1617880261,
#           'sunset': 1617919110,
#           'type': 1},
#   'timezone': -10800,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 230, 'speed': 13.38}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 68.3751, 'lon': 17.5988},
#   'dt': 1617907418,
#   'id': 3144987,
#   'main': {'feels_like': 269.05,
#            'humidity': 74,
#            'pressure': 997,
#            'temp': 271.15,
#            'temp_max': 271.15,
#            'temp_min': 271.15},
#   'name': 'Beisfjord',
#   'sys': {'country': 'NO',
#           'id': 1614,
#           'sunrise': 1617852393,
#           'sunset': 1617905754,
#           'type': 1},
#   'timezone': 7200,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 0, 'speed': 1.54}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': -2.6741, 'lon': 141.3028},
#   'dt': 1617907419,
#   'id': 2084442,
#   'main': {'feels_like': 299.12,
#            'grnd_level': 1005,
#            'humidity': 89,
#            'pressure': 1008,
#            'sea_level': 1008,
#            'temp': 298.23,
#            'temp_max': 298.23,
#            'temp_min': 298.23},
#   'name': 'Vanimo',
#   'sys': {'country': 'PG', 'sunrise': 1617914057, 'sunset': 1617957490},
#   'timezone': 36000,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 283, 'gust': 2.28, 'speed': 1.88}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 71.2906, 'lon': -156.7887},
#   'dt': 1617907214,
#   'id': 5880054,
#   'main': {'feels_like': 236.26,
#            'humidity': 63,
#            'pressure': 1026,
#            'temp': 246.15,
#            'temp_max': 246.15,
#            'temp_min': 246.15},
#   'name': 'Barrow',
#   'sys': {'country': 'US',
#           'id': 7649,
#           'sunrise': 1617893186,
#           'sunset': 1617948651,
#           'type': 1},
#   'timezone': -28800,
#   'visibility': 4828,
#   'weather': [{'description': 'light snow',
#                'icon': '13d',
#                'id': 600,
#                'main': 'Snow'}],
#   'wind': {'deg': 300, 'speed': 3.6}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 13.0667, 'lon': -59.5333},
#   'dt': 1617907419,
#   'id': 3373652,
#   'main': {'feels_like': 304.86,
#            'humidity': 54,
#            'pressure': 1012,
#            'temp': 303.15,
#            'temp_max': 303.15,
#            'temp_min': 303.15},
#   'name': 'Oistins',
#   'sys': {'country': 'BB',
#           'id': 8772,
#           'sunrise': 1617875364,
#           'sunset': 1617919799,
#           'type': 1},
#   'timezone': -14400,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 120, 'speed': 6.17}},
#  {'base': 'stations',
#   'clouds': {'all': 4},
#   'cod': 200,
#   'coord': {'lat': -34.5322, 'lon': 20.0403},
#   'dt': 1617907361,
#   'id': 1015776,
#   'main': {'feels_like': 287.06,
#            'humidity': 94,
#            'pressure': 1021,
#            'temp': 287.15,
#            'temp_max': 287.15,
#            'temp_min': 287.15},
#   'name': 'Bredasdorp',
#   'sys': {'country': 'ZA',
#           'id': 1966,
#           'sunrise': 1617857850,
#           'sunset': 1617899125,
#           'type': 1},
#   'timezone': 7200,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 260, 'speed': 1.54}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 77.484, 'lon': -69.3632},
#   'dt': 1617907420,
#   'id': 3831208,
#   'main': {'feels_like': 261.89,
#            'grnd_level': 1018,
#            'humidity': 71,
#            'pressure': 1022,
#            'sea_level': 1022,
#            'temp': 261.89,
#            'temp_max': 261.89,
#            'temp_min': 261.89},
#   'name': 'Qaanaaq',
#   'sys': {'country': 'GL', 'sunrise': 1617868634, 'sunset': 1617931247},
#   'timezone': -10800,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 20, 'gust': 1.09, 'speed': 1.07}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 65.75, 'lon': 150.85},
#   'dt': 1617907420,
#   'id': 2119283,
#   'main': {'feels_like': 253.83,
#            'grnd_level': 1023,
#            'humidity': 95,
#            'pressure': 1028,
#            'sea_level': 1028,
#            'temp': 260.74,
#            'temp_max': 260.74,
#            'temp_min': 260.74},
#   'name': 'Zyryanka',
#   'snow': {'1h': 0.15},
#   'sys': {'country': 'RU', 'sunrise': 1617907291, 'sunset': 1617959674},
#   'timezone': 39600,
#   'visibility': 274,
#   'weather': [{'description': 'light snow',
#                'icon': '13d',
#                'id': 600,
#                'main': 'Snow'}],
#   'wind': {'deg': 329, 'gust': 6.01, 'speed': 3.79}},
#  {'base': 'stations',
#   'clouds': {'all': 5},
#   'cod': 200,
#   'coord': {'lat': -46.1333, 'lon': 167.6833},
#   'dt': 1617907420,
#   'id': 2180815,
#   'main': {'feels_like': 277.59,
#            'humidity': 95,
#            'pressure': 1012,
#            'temp': 277.59,
#            'temp_max': 277.59,
#            'temp_min': 277.59},
#   'name': 'Tuatapere',
#   'sys': {'country': 'NZ',
#           'id': 2008959,
#           'sunrise': 1617909435,
#           'sunset': 1617949452,
#           'type': 3},
#   'timezone': 43200,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 20, 'gust': 1.34, 'speed': 0.45}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 50.2536, 'lon': -96.0612},
#   'dt': 1617907421,
#   'id': 6014443,
#   'main': {'feels_like': 279.78,
#            'humidity': 99,
#            'pressure': 1008,
#            'temp': 282.04,
#            'temp_max': 282.04,
#            'temp_min': 282.04},
#   'name': 'Lac du Bonnet',
#   'sys': {'country': 'CA',
#           'id': 19218,
#           'sunrise': 1617882277,
#           'sunset': 1617930416,
#           'type': 3},
#   'timezone': -18000,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 129, 'gust': 4.02, 'speed': 4.02}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': -8.7676, 'lon': 160.7034},
#   'dt': 1617907421,
#   'id': 2109701,
#   'main': {'feels_like': 298.14,
#            'grnd_level': 1001,
#            'humidity': 85,
#            'pressure': 1008,
#            'sea_level': 1008,
#            'temp': 297.44,
#            'temp_max': 297.44,
#            'temp_min': 297.44},
#   'name': 'Auki',
#   'sys': {'country': 'SB', 'sunrise': 1617909594, 'sunset': 1617952643},
#   'timezone': 39600,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 11, 'gust': 2.47, 'speed': 2.24}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': -20.5167, 'lon': 57.5167},
#   'dt': 1617907422,
#   'id': 933995,
#   'main': {'feels_like': 299.15,
#            'humidity': 78,
#            'pressure': 1017,
#            'temp': 299.15,
#            'temp_max': 299.15,
#            'temp_min': 299.15},
#   'name': 'Souillac',
#   'sys': {'country': 'MU',
#           'id': 2061,
#           'sunrise': 1617848333,
#           'sunset': 1617890657,
#           'type': 1},
#   'timezone': 14400,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 100, 'speed': 6.69}},
#  {'base': 'stations',
#   'clouds': {'all': 14},
#   'cod': 200,
#   'coord': {'lat': -0.6, 'lon': 73.0833},
#   'dt': 1617907422,
#   'id': 1282256,
#   'main': {'feels_like': 304.08,
#            'grnd_level': 1010,
#            'humidity': 68,
#            'pressure': 1010,
#            'sea_level': 1010,
#            'temp': 301.43,
#            'temp_max': 301.43,
#            'temp_min': 301.43},
#   'name': 'Hithadhoo',
#   'sys': {'country': 'MV', 'sunrise': 1617843977, 'sunset': 1617887542},
#   'timezone': 18000,
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 285, 'gust': 6.77, 'speed': 6.59}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 28.6585, 'lon': -17.9182},
#   'dt': 1617907311,
#   'id': 2514651,
#   'main': {'feels_like': 291.83,
#            'humidity': 78,
#            'pressure': 1018,
#            'temp': 291.87,
#            'temp_max': 294.15,
#            'temp_min': 290.37},
#   'name': 'Los Llanos de Aridane',
#   'sys': {'country': 'ES',
#           'id': 2377,
#           'sunrise': 1617864803,
#           'sunset': 1617910389,
#           'type': 1},
#   'timezone': 3600,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 322, 'gust': 2.7, 'speed': 2.64}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -21.2078, 'lon': -159.775},
#   'dt': 1617907143,
#   'id': 4035715,
#   'main': {'feels_like': 299.16,
#            'humidity': 94,
#            'pressure': 1011,
#            'temp': 298.15,
#            'temp_max': 298.15,
#            'temp_min': 298.15},
#   'name': 'Avarua',
#   'sys': {'country': 'CK',
#           'id': 7271,
#           'sunrise': 1617900517,
#           'sunset': 1617942753,
#           'type': 1},
#   'timezone': -36000,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 50, 'speed': 2.57}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 66.7697, 'lon': 123.3711},
#   'dt': 1617907423,
#   'id': 2012530,
#   'main': {'feels_like': 255.96,
#            'grnd_level': 1011,
#            'humidity': 94,
#            'pressure': 1017,
#            'sea_level': 1017,
#            'temp': 264.03,
#            'temp_max': 264.03,
#            'temp_min': 264.03},
#   'name': 'Zhigansk',
#   'sys': {'country': 'RU', 'sunrise': 1617913635, 'sunset': 1617966518},
#   'timezone': 32400,
#   'visibility': 393,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 15, 'gust': 10.38, 'speed': 6.25}},
#  {'base': 'stations',
#   'clouds': {'all': 4},
#   'cod': 200,
#   'coord': {'lat': 39.05, 'lon': -27.9833},
#   'dt': 1617907423,
#   'id': 3372964,
#   'main': {'feels_like': 288,
#            'grnd_level': 1003,
#            'humidity': 87,
#            'pressure': 1012,
#            'sea_level': 1012,
#            'temp': 288.17,
#            'temp_max': 288.17,
#            'temp_min': 288.17},
#   'name': 'Lagoa',
#   'sys': {'country': 'PT', 'sunrise': 1617866717, 'sunset': 1617913305},
#   'timezone': 0,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 305, 'gust': 11.27, 'speed': 9.69}},
#  {'base': 'stations',
#   'clouds': {'all': 10},
#   'cod': 200,
#   'coord': {'lat': -25.2406, 'lon': 130.9889},
#   'dt': 1617907424,
#   'id': 6355222,
#   'main': {'feels_like': 289.16,
#            'humidity': 48,
#            'pressure': 1011,
#            'temp': 290.15,
#            'temp_max': 290.15,
#            'temp_min': 290.15},
#   'name': 'Yulara',
#   'sys': {'country': 'AU',
#           'id': 9487,
#           'sunrise': 1617917282,
#           'sunset': 1617959215,
#           'type': 1},
#   'timezone': 34200,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 180, 'speed': 1.54}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 63.7506, 'lon': -68.5145},
#   'dt': 1617907424,
#   'id': 5983720,
#   'main': {'feels_like': 273.62,
#            'humidity': 65,
#            'pressure': 1011,
#            'temp': 276.15,
#            'temp_max': 276.15,
#            'temp_min': 276.15},
#   'name': 'Iqaluit',
#   'sys': {'country': 'CA',
#           'id': 797,
#           'sunrise': 1617874024,
#           'sunset': 1617925450,
#           'type': 1},
#   'timezone': -14400,
#   'visibility': 2414,
#   'weather': [{'description': 'light snow',
#                'icon': '13d',
#                'id': 600,
#                'main': 'Snow'}],
#   'wind': {'deg': 180, 'speed': 2.57}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': -20.3428, 'lon': 57.7575},
#   'dt': 1617907424,
#   'id': 1106677,
#   'main': {'feels_like': 299.46,
#            'humidity': 78,
#            'pressure': 1017,
#            'temp': 299.46,
#            'temp_max': 299.82,
#            'temp_min': 299.15},
#   'name': 'Bambous Virieux',
#   'rain': {'1h': 0.14},
#   'sys': {'country': 'MU',
#           'id': 2061,
#           'sunrise': 1617848269,
#           'sunset': 1617890605,
#           'type': 1},
#   'timezone': 14400,
#   'visibility': 10000,
#   'weather': [{'description': 'light rain',
#                'icon': '10n',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 100, 'speed': 6.69}},
#  {'base': 'stations',
#   'clouds': {'all': 1},
#   'cod': 200,
#   'coord': {'lat': 22.0752, 'lon': -159.319},
#   'dt': 1617907419,
#   'id': 5848280,
#   'main': {'feels_like': 295.12,
#            'humidity': 53,
#            'pressure': 1021,
#            'temp': 295.45,
#            'temp_max': 297.15,
#            'temp_min': 294.82},
#   'name': 'Kapaa',
#   'rain': {'1h': 0.13},
#   'sys': {'country': 'US',
#           'id': 7873,
#           'sunrise': 1617898979,
#           'sunset': 1617944072,
#           'type': 1},
#   'timezone': -36000,
#   'visibility': 10000,
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 50, 'speed': 7.72}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -23.3156, 'lon': -46.2214},
#   'dt': 1617907136,
#   'id': 3450188,
#   'main': {'feels_like': 298.57,
#            'humidity': 41,
#            'pressure': 1021,
#            'temp': 298.87,
#            'temp_max': 299.26,
#            'temp_min': 298.15},
#   'name': 'Santa Isabel',
#   'sys': {'country': 'BR',
#           'id': 8379,
#           'sunrise': 1617873331,
#           'sunset': 1617915444,
#           'type': 1},
#   'timezone': -10800,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 80, 'speed': 5.14}},
#  {'base': 'stations',
#   'clouds': {'all': 88},
#   'cod': 200,
#   'coord': {'lat': 46.6806, 'lon': 113.2792},
#   'dt': 1617907425,
#   'id': 2032614,
#   'main': {'feels_like': 275.7,
#            'grnd_level': 904,
#            'humidity': 29,
#            'pressure': 1019,
#            'sea_level': 1019,
#            'temp': 278.02,
#            'temp_max': 278.02,
#            'temp_min': 278.02},
#   'name': 'Baruun-Urt',
#   'sys': {'country': 'MN', 'sunrise': 1617918666, 'sunset': 1617966330},
#   'timezone': 28800,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 222, 'gust': 2.84, 'speed': 2.74}},
#  {'base': 'stations',
#   'clouds': {'all': 12},
#   'cod': 200,
#   'coord': {'lat': 73.5069, 'lon': 80.5464},
#   'dt': 1617907425,
#   'id': 1507390,
#   'main': {'feels_like': 246.15,
#            'grnd_level': 1028,
#            'humidity': 79,
#            'pressure': 1034,
#            'sea_level': 1034,
#            'temp': 255.92,
#            'temp_max': 255.92,
#            'temp_min': 255.92},
#   'name': 'Dikson',
#   'sys': {'country': 'RU', 'sunrise': 1617921547, 'sunset': 1617979158},
#   'timezone': 25200,
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 181, 'gust': 10.92, 'speed': 5.61}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 44.3667, 'lon': 28.45},
#   'dt': 1617907426,
#   'id': 673382,
#   'main': {'feels_like': 274.75,
#            'humidity': 60,
#            'pressure': 1022,
#            'temp': 277.1,
#            'temp_max': 277.15,
#            'temp_min': 277.04},
#   'name': 'Mihail Kogălniceanu',
#   'sys': {'country': 'RO',
#           'id': 6912,
#           'sunrise': 1617852870,
#           'sunset': 1617900069,
#           'type': 1},
#   'timezone': 10800,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 300, 'speed': 2.57}},
#  {'base': 'stations',
#   'clouds': {'all': 1},
#   'cod': 200,
#   'coord': {'lat': 28.017, 'lon': -97.5169},
#   'dt': 1617907426,
#   'id': 4726521,
#   'main': {'feels_like': 309.27,
#            'humidity': 55,
#            'pressure': 1010,
#            'temp': 305.38,
#            'temp_max': 306.48,
#            'temp_min': 304.15},
#   'name': 'San Patricio',
#   'sys': {'country': 'US',
#           'id': 3705,
#           'sunrise': 1617883919,
#           'sunset': 1617929473,
#           'type': 1},
#   'timezone': -18000,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 130, 'gust': 8.23, 'speed': 4.12}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 47.6666, 'lon': -52.7314},
#   'dt': 1617907427,
#   'id': 6167817,
#   'main': {'feels_like': 272.43,
#            'humidity': 100,
#            'pressure': 1013,
#            'temp': 277.1,
#            'temp_max': 278.71,
#            'temp_min': 275.15},
#   'name': 'Torbay',
#   'rain': {'1h': 0.38},
#   'sys': {'country': 'CA',
#           'id': 998,
#           'sunrise': 1617872098,
#           'sunset': 1617919801,
#           'type': 1},
#   'timezone': -9000,
#   'visibility': 201,
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'},
#               {'description': 'light intensity drizzle',
#                'icon': '09d',
#                'id': 300,
#                'main': 'Drizzle'},
#               {'description': 'fog', 'icon': '50d', 'id': 741, 'main': 'Fog'}],
#   'wind': {'deg': 50, 'gust': 9.77, 'speed': 6.69}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -4.5772, 'lon': -81.2719},
#   'dt': 1617907427,
#   'id': 3691582,
#   'main': {'feels_like': 309.16,
#            'humidity': 49,
#            'pressure': 1009,
#            'temp': 306.15,
#            'temp_max': 306.15,
#            'temp_min': 306.15},
#   'name': 'Talara',
#   'sys': {'country': 'PE',
#           'id': 8685,
#           'sunrise': 1617881139,
#           'sunset': 1617924457,
#           'type': 1},
#   'timezone': -18000,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 180, 'speed': 6.17}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 57.4035, 'lon': 45.0916},
#   'dt': 1617907428,
#   'id': 476982,
#   'main': {'feels_like': 269.41,
#            'grnd_level': 993,
#            'humidity': 79,
#            'pressure': 1008,
#            'sea_level': 1008,
#            'temp': 274.89,
#            'temp_max': 274.89,
#            'temp_min': 274.89},
#   'name': 'Varnavino',
#   'sys': {'country': 'RU', 'sunrise': 1617847747, 'sunset': 1617897206},
#   'timezone': 10800,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 231, 'gust': 14.33, 'speed': 7.16}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 45.5234, 'lon': -122.6762},
#   'dt': 1617907082,
#   'id': 5746545,
#   'main': {'feels_like': 280.25,
#            'humidity': 57,
#            'pressure': 1027,
#            'temp': 282.64,
#            'temp_max': 284.26,
#            'temp_min': 281.48},
#   'name': 'Portland',
#   'sys': {'country': 'US',
#           'id': 5321,
#           'sunrise': 1617889017,
#           'sunset': 1617936449,
#           'type': 1},
#   'timezone': -25200,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 320, 'speed': 4.63}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 71.6872, 'lon': 128.8694},
#   'dt': 1617907429,
#   'id': 2015306,
#   'main': {'feels_like': 237.64,
#            'grnd_level': 1026,
#            'humidity': 100,
#            'pressure': 1032,
#            'sea_level': 1032,
#            'temp': 246.49,
#            'temp_max': 246.49,
#            'temp_min': 246.49},
#   'name': 'Tiksi',
#   'sys': {'country': 'RU', 'sunrise': 1617910810, 'sunset': 1617966705},
#   'timezone': 32400,
#   'visibility': 1413,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 1, 'gust': 3.24, 'speed': 2.99}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 32},
#   'cod': 200,
#   'coord': {'lat': 6.4788, 'lon': 79.9828},
#   'dt': 1617907429,
#   'id': 1249931,
#   'main': {'feels_like': 299.78,
#            'grnd_level': 1009,
#            'humidity': 79,
#            'pressure': 1010,
#            'sea_level': 1010,
#            'temp': 299.07,
#            'temp_max': 299.07,
#            'temp_min': 299.07},
#   'name': 'Beruwala',
#   'sys': {'country': 'LK', 'sunrise': 1617928478, 'sunset': 1617972497},
#   'timezone': 19800,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 231, 'gust': 1.54, 'speed': 0.83}},
#  {'base': 'stations',
#   'clouds': {'all': 6},
#   'cod': 200,
#   'coord': {'lat': -34.4187, 'lon': 19.2345},
#   'dt': 1617907430,
#   'id': 3366880,
#   'main': {'feels_like': 288.03,
#            'humidity': 89,
#            'pressure': 1022,
#            'temp': 288.15,
#            'temp_max': 288.15,
#            'temp_min': 288.15},
#   'name': 'Hermanus',
#   'sys': {'country': 'ZA',
#           'id': 2006131,
#           'sunrise': 1617858039,
#           'sunset': 1617899323,
#           'type': 3},
#   'timezone': 7200,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 122, 'gust': 1.55, 'speed': 1.25}},
#  {'base': 'stations',
#   'clouds': {'all': 22},
#   'cod': 200,
#   'coord': {'lat': 11.0167, 'lon': 29.7167},
#   'dt': 1617907430,
#   'id': 373141,
#   'main': {'feels_like': 303.32,
#            'grnd_level': 950,
#            'humidity': 9,
#            'pressure': 1005,
#            'sea_level': 1005,
#            'temp': 305.62,
#            'temp_max': 305.62,
#            'temp_min': 305.62},
#   'name': 'Kaduqli',
#   'sys': {'country': 'SD', 'sunrise': 1617854020, 'sunset': 1617898311},
#   'timezone': 7200,
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 49, 'gust': 2.01, 'speed': 1.64}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 72.7868, 'lon': -56.1549},
#   'dt': 1617907430,
#   'id': 3418910,
#   'main': {'feels_like': 264.32,
#            'grnd_level': 1015,
#            'humidity': 66,
#            'pressure': 1015,
#            'sea_level': 1015,
#            'temp': 268.98,
#            'temp_max': 268.98,
#            'temp_min': 268.98},
#   'name': 'Upernavik',
#   'sys': {'country': 'GL', 'sunrise': 1617868519, 'sunset': 1617925023},
#   'timezone': -7200,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 53, 'gust': 4.43, 'speed': 3.33}},
#  {'base': 'stations',
#   'clouds': {'all': 1},
#   'cod': 200,
#   'coord': {'lat': 64.5011, 'lon': -165.4064},
#   'dt': 1617907431,
#   'id': 5870133,
#   'main': {'feels_like': 239.25,
#            'humidity': 64,
#            'pressure': 1033,
#            'temp': 249.65,
#            'temp_max': 251.15,
#            'temp_min': 248.71},
#   'name': 'Nome',
#   'sys': {'country': 'US',
#           'id': 7770,
#           'sunrise': 1617897078,
#           'sunset': 1617948894,
#           'type': 1},
#   'timezone': -28800,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 340, 'speed': 4.63}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': -22.9661, 'lon': -42.0278},
#   'dt': 1617907431,
#   'id': 3471451,
#   'main': {'feels_like': 299.22,
#            'humidity': 78,
#            'pressure': 1021,
#            'temp': 298.58,
#            'temp_max': 299.15,
#            'temp_min': 298.15},
#   'name': 'Arraial do Cabo',
#   'sys': {'country': 'BR',
#           'id': 8326,
#           'sunrise': 1617872312,
#           'sunset': 1617914450,
#           'type': 1},
#   'timezone': -10800,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 70, 'speed': 5.14}},
#  {'base': 'stations',
#   'clouds': {'all': 12},
#   'cod': 200,
#   'coord': {'lat': 69.0125, 'lon': 23.0412},
#   'dt': 1617907432,
#   'id': 779330,
#   'main': {'feels_like': 251.41,
#            'grnd_level': 958,
#            'humidity': 99,
#            'pressure': 999,
#            'sea_level': 999,
#            'temp': 256.07,
#            'temp_max': 256.07,
#            'temp_min': 256.07},
#   'name': 'Kautokeino',
#   'sys': {'country': 'NO', 'sunrise': 1617850915, 'sunset': 1617904620},
#   'timezone': 7200,
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 333, 'gust': 1.61, 'speed': 1.71}},
#  {'base': 'stations',
#   'clouds': {'all': 9},
#   'cod': 200,
#   'coord': {'lat': -46.6, 'lon': 168.3333},
#   'dt': 1617907432,
#   'id': 2206939,
#   'main': {'feels_like': 277.59,
#            'humidity': 95,
#            'pressure': 1012,
#            'temp': 277.59,
#            'temp_max': 277.59,
#            'temp_min': 277.59},
#   'name': 'Bluff',
#   'sys': {'country': 'NZ',
#           'id': 2008959,
#           'sunrise': 1617909308,
#           'sunset': 1617949267,
#           'type': 3},
#   'timezone': 43200,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 20, 'gust': 1.34, 'speed': 0.45}},
#  {'base': 'stations',
#   'clouds': {'all': 10},
#   'cod': 200,
#   'coord': {'lat': -0.4536, 'lon': 39.6401},
#   'dt': 1617907432,
#   'id': 197745,
#   'main': {'feels_like': 303.51,
#            'grnd_level': 995,
#            'humidity': 66,
#            'pressure': 1011,
#            'sea_level': 1011,
#            'temp': 301.27,
#            'temp_max': 301.27,
#            'temp_min': 301.27},
#   'name': 'Garissa',
#   'rain': {'1h': 0.58},
#   'sys': {'country': 'KE', 'sunrise': 1617851998, 'sunset': 1617895572},
#   'timezone': 10800,
#   'visibility': 10000,
#   'weather': [{'description': 'light rain',
#                'icon': '10n',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 140, 'gust': 11.18, 'speed': 8.34}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 99},
#   'cod': 200,
#   'coord': {'lat': 10.5, 'lon': 10},
#   'dt': 1617907433,
#   'id': 2347468,
#   'main': {'feels_like': 302.92,
#            'grnd_level': 946,
#            'humidity': 11,
#            'pressure': 1006,
#            'sea_level': 1006,
#            'temp': 305.16,
#            'temp_max': 305.16,
#            'temp_min': 305.16},
#   'name': 'Bauchi',
#   'sys': {'country': 'NG', 'sunrise': 1617858767, 'sunset': 1617903026},
#   'timezone': 3600,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 22, 'gust': 2.51, 'speed': 2.39}},
#  {'base': 'stations',
#   'clouds': {'all': 6},
#   'cod': 200,
#   'coord': {'lat': -37.6167, 'lon': -73.65},
#   'dt': 1617907211,
#   'id': 3883457,
#   'main': {'feels_like': 288.14,
#            'grnd_level': 1013,
#            'humidity': 67,
#            'pressure': 1017,
#            'sea_level': 1017,
#            'temp': 288.77,
#            'temp_max': 288.77,
#            'temp_min': 288.77},
#   'name': 'Lebu',
#   'sys': {'country': 'CL', 'sunrise': 1617880485, 'sunset': 1617921453},
#   'timezone': -14400,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 301, 'gust': 4.41, 'speed': 3.02}},
#  {'base': 'stations',
#   'clouds': {'all': 8},
#   'cod': 200,
#   'coord': {'lat': -35.3333, 'lon': -72.4167},
#   'dt': 1617907433,
#   'id': 3893726,
#   'main': {'feels_like': 290.03,
#            'grnd_level': 1015,
#            'humidity': 65,
#            'pressure': 1018,
#            'sea_level': 1018,
#            'temp': 290.54,
#            'temp_max': 290.54,
#            'temp_min': 290.54},
#   'name': 'Constitución',
#   'sys': {'country': 'CL', 'sunrise': 1617880086, 'sunset': 1617921260},
#   'timezone': -14400,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 276, 'gust': 3.79, 'speed': 2.98}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 26},
#   'cod': 200,
#   'coord': {'lat': 66.0317, 'lon': 60.1659},
#   'dt': 1617907434,
#   'id': 1505579,
#   'main': {'feels_like': 271.19,
#            'grnd_level': 1009,
#            'humidity': 81,
#            'pressure': 1016,
#            'sea_level': 1016,
#            'temp': 276.34,
#            'temp_max': 276.34,
#            'temp_min': 276.34},
#   'name': 'Inta',
#   'sys': {'country': 'RU', 'sunrise': 1617842768, 'sunset': 1617894951},
#   'timezone': 10800,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 166, 'gust': 13.27, 'speed': 7.39}},
#  {'base': 'stations',
#   'clouds': {'all': 21},
#   'cod': 200,
#   'coord': {'lat': -45.4167, 'lon': 167.7167},
#   'dt': 1617907434,
#   'id': 2181625,
#   'main': {'feels_like': 280.09,
#            'grnd_level': 988,
#            'humidity': 91,
#            'pressure': 1014,
#            'sea_level': 1014,
#            'temp': 280.09,
#            'temp_max': 280.09,
#            'temp_min': 280.09},
#   'name': 'Te Anau',
#   'sys': {'country': 'NZ', 'sunrise': 1617909384, 'sunset': 1617949487},
#   'timezone': 43200,
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 20, 'gust': 2.81, 'speed': 1.2}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': -33.6971, 'lon': -53.4616},
#   'dt': 1617907435,
#   'id': 3443061,
#   'main': {'feels_like': 299.63,
#            'grnd_level': 1012,
#            'humidity': 58,
#            'pressure': 1014,
#            'sea_level': 1014,
#            'temp': 299.63,
#            'temp_max': 299.63,
#            'temp_min': 299.63},
#   'name': 'Chui',
#   'sys': {'country': 'UY', 'sunrise': 1617875465, 'sunset': 1617916785},
#   'timezone': -10800,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
# ...
#           'sunrise': 1617866515,
#           'sunset': 1617913068,
#           'type': 1},
#   'timezone': 0,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 297, 'gust': 12.18, 'speed': 9.09}},
#  {'base': 'stations',
#   'clouds': {'all': 98},
#   'cod': 200,
#   'coord': {'lat': -1.5911, 'lon': 31.1403},
#   'dt': 1617907618,
#   'id': 161022,
#   'main': {'feels_like': 287.82,
#            'grnd_level': 838,
#            'humidity': 96,
#            'pressure': 1014,
#            'sea_level': 1014,
#            'temp': 287.79,
#            'temp_max': 287.79,
#            'temp_min': 287.79},
#   'name': 'Bugene',
#   'rain': {'1h': 0.71},
#   'sys': {'country': 'TZ', 'sunrise': 1617854072, 'sunset': 1617897577},
#   'timezone': 10800,
#   'visibility': 10000,
#   'weather': [{'description': 'light rain',
#                'icon': '10n',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 226, 'gust': 1.15, 'speed': 1.21}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': -0.0921, 'lon': 11.9385},
#   'dt': 1617907619,
#   'id': 2401495,
#   'main': {'feels_like': 298.47,
#            'grnd_level': 987,
#            'humidity': 94,
#            'pressure': 1009,
#            'sea_level': 1009,
#            'temp': 297.52,
#            'temp_max': 297.52,
#            'temp_min': 297.52},
#   'name': 'Booué',
#   'rain': {'1h': 1.06},
#   'sys': {'country': 'GA', 'sunrise': 1617858634, 'sunset': 1617902230},
#   'timezone': 3600,
#   'visibility': 10000,
#   'weather': [{'description': 'moderate rain',
#                'icon': '10n',
#                'id': 501,
#                'main': 'Rain'}],
#   'wind': {'deg': 55, 'gust': 4.57, 'speed': 1.77}},
#  {'base': 'stations',
#   'clouds': {'all': 16},
#   'cod': 200,
#   'coord': {'lat': -10.3845, 'lon': 28.698},
#   'dt': 1617907619,
#   'id': 902721,
#   'main': {'feels_like': 292.13,
#            'grnd_level': 908,
#            'humidity': 93,
#            'pressure': 1015,
#            'sea_level': 1015,
#            'temp': 291.78,
#            'temp_max': 291.78,
#            'temp_min': 291.78},
#   'name': 'Mwense',
#   'sys': {'country': 'ZM', 'sunrise': 1617854927, 'sunset': 1617897894},
#   'timezone': 7200,
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 132, 'gust': 1.84, 'speed': 1.65}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 6.1241, 'lon': 81.1185},
#   'dt': 1617907620,
#   'id': 1244926,
#   'main': {'feels_like': 298.22,
#            'humidity': 100,
#            'pressure': 1010,
#            'temp': 297.15,
#            'temp_max': 297.15,
#            'temp_min': 297.15},
#   'name': 'Hambantota',
#   'sys': {'country': 'LK',
#           'id': 9124,
#           'sunrise': 1617928217,
#           'sunset': 1617972213,
#           'type': 1},
#   'timezone': 19800,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 264, 'gust': 3.65, 'speed': 3.17}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': -12.7406, 'lon': -60.1458},
#   'dt': 1617907620,
#   'id': 3924679,
#   'main': {'feels_like': 298.06,
#            'humidity': 94,
#            'pressure': 1013,
#            'temp': 297.15,
#            'temp_max': 297.15,
#            'temp_min': 297.15},
#   'name': 'Vilhena',
#   'sys': {'country': 'BR',
#           'id': 8457,
#           'sunrise': 1617876323,
#           'sunset': 1617919134,
#           'type': 1},
#   'timezone': -14400,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 330, 'speed': 2.06}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -11.5714, 'lon': -77.2672},
#   'dt': 1617907620,
#   'id': 3944399,
#   'main': {'feels_like': 295.94,
#            'humidity': 68,
#            'pressure': 1012,
#            'temp': 295.84,
#            'temp_max': 296.15,
#            'temp_min': 294.82},
#   'name': 'Chancay',
#   'sys': {'country': 'PE',
#           'id': 8682,
#           'sunrise': 1617880396,
#           'sunset': 1617923278,
#           'type': 1},
#   'timezone': -18000,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 280, 'speed': 3.09}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 28.3667, 'lon': 129.4833},
#   'dt': 1617907621,
#   'id': 1855540,
#   'main': {'feels_like': 289.43,
#            'grnd_level': 989,
#            'humidity': 69,
#            'pressure': 1016,
#            'sea_level': 1016,
#            'temp': 289.9,
#            'temp_max': 289.9,
#            'temp_min': 289.9},
#   'name': 'Naze',
#   'sys': {'country': 'JP', 'sunrise': 1617915800, 'sunset': 1617961420},
#   'timezone': 32400,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 32, 'gust': 3.64, 'speed': 2.78}},
#  {'base': 'stations',
#   'clouds': {'all': 70},
#   'cod': 200,
#   'coord': {'lat': 26.5412, 'lon': -77.0636},
#   'dt': 1617907621,
#   'id': 3571913,
#   'main': {'feels_like': 295.08,
#            'grnd_level': 1017,
#            'humidity': 53,
#            'pressure': 1018,
#            'sea_level': 1018,
#            'temp': 295.41,
#            'temp_max': 295.41,
#            'temp_min': 295.41},
#   'name': 'Marsh Harbour',
#   'sys': {'country': 'BS', 'sunrise': 1617879075, 'sunset': 1617924501},
#   'timezone': -14400,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 92, 'gust': 3.2, 'speed': 3.56}},
#  {'base': 'stations',
#   'clouds': {'all': 6},
#   'cod': 200,
#   'coord': {'lat': 25.7, 'lon': -99.2333},
#   'dt': 1617907622,
#   'id': 3530839,
#   'main': {'feels_like': 307.58,
#            'grnd_level': 992,
#            'humidity': 29,
#            'pressure': 1007,
#            'sea_level': 1007,
#            'temp': 308.12,
#            'temp_max': 308.12,
#            'temp_min': 308.12},
#   'name': 'China',
#   'sys': {'country': 'MX', 'sunrise': 1617884426, 'sunset': 1617929789},
#   'timezone': -18000,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 145, 'gust': 4.17, 'speed': 4.34}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 50.0544, 'lon': 72.9483},
#   'dt': 1617907622,
#   'id': 1518262,
#   'main': {'feels_like': 277.85,
#            'humidity': 66,
#            'pressure': 1022,
#            'temp': 281.15,
#            'temp_max': 281.15,
#            'temp_min': 281.15},
#   'name': 'Temirtau',
#   'sys': {'country': 'KZ',
#           'id': 8827,
#           'sunrise': 1617928064,
#           'sunset': 1617976287,
#           'type': 1},
#   'timezone': 21600,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 180, 'speed': 6}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 22.2769, 'lon': 113.5678},
#   'dt': 1617907622,
#   'id': 1790437,
#   'main': {'feels_like': 293.66,
#            'humidity': 94,
#            'pressure': 1014,
#            'temp': 293.15,
#            'temp_max': 293.15,
#            'temp_min': 293.15},
#   'name': 'Zhuhai',
#   'rain': {'1h': 0.2},
#   'sys': {'country': 'CN',
#           'id': 9204,
#           'sunrise': 1617919865,
#           'sunset': 1617964992,
#           'type': 1},
#   'timezone': 28800,
#   'visibility': 7000,
#   'weather': [{'description': 'light rain',
#                'icon': '10n',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 10, 'speed': 7.2}},
#  {'base': 'stations',
#   'clouds': {'all': 30},
#   'cod': 200,
#   'coord': {'lat': 56.1325, 'lon': 101.6142},
#   'dt': 1617907623,
#   'id': 2051523,
#   'main': {'feels_like': 268.23,
#            'humidity': 74,
#            'pressure': 1023,
#            'temp': 273.15,
#            'temp_max': 273.15,
#            'temp_min': 273.15},
#   'name': 'Bratsk',
#   'sys': {'country': 'RU',
#           'id': 8892,
#           'sunrise': 1617920595,
#           'sunset': 1617969999,
#           'type': 1},
#   'timezone': 28800,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 280, 'speed': 5}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 12.5847, 'lon': -81.7006},
#   'dt': 1617907623,
#   'id': 3670218,
#   'main': {'feels_like': 307.25,
#            'humidity': 66,
#            'pressure': 1011,
#            'temp': 303.15,
#            'temp_max': 303.15,
#            'temp_min': 303.15},
#   'name': 'San Andrés',
#   'sys': {'country': 'CO',
#           'id': 8623,
#           'sunrise': 1617880698,
#           'sunset': 1617925104,
#           'type': 1},
#   'timezone': -18000,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 70, 'speed': 6.17}},
#  {'base': 'stations',
#   'clouds': {'all': 83},
#   'cod': 200,
#   'coord': {'lat': 52.9821, 'lon': 84.6757},
#   'dt': 1617907623,
#   'id': 1489209,
#   'main': {'feels_like': 269.49,
#            'grnd_level': 1002,
#            'humidity': 95,
#            'pressure': 1029,
#            'sea_level': 1029,
#            'temp': 272.35,
#            'temp_max': 272.35,
#            'temp_min': 272.35},
#   'name': 'Troitskoye',
#   'sys': {'country': 'RU', 'sunrise': 1617924987, 'sunset': 1617973736},
#   'timezone': 25200,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 52, 'gust': 3.53, 'speed': 2.22}},
#  {'base': 'stations',
#   'clouds': {'all': 44},
#   'cod': 200,
#   'coord': {'lat': -22.6667, 'lon': 167.4833},
#   'dt': 1617907589,
#   'id': 2137773,
#   'main': {'feels_like': 299.11,
#            'grnd_level': 1000,
#            'humidity': 80,
#            'pressure': 1010,
#            'sea_level': 1010,
#            'temp': 298.44,
#            'temp_max': 298.44,
#            'temp_min': 298.44},
#   'name': 'Vao',
#   'sys': {'country': 'NC', 'sunrise': 1617908428, 'sunset': 1617950555},
#   'timezone': 39600,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 22, 'gust': 10.87, 'speed': 9.98}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 34.7667, 'lon': 32.4167},
#   'dt': 1617907383,
#   'id': 146214,
#   'main': {'feels_like': 285.85,
#            'humidity': 77,
#            'pressure': 1015,
#            'temp': 286.45,
#            'temp_max': 288.15,
#            'temp_min': 284.26},
#   'name': 'Paphos',
#   'sys': {'country': 'CY',
#           'id': 6374,
#           'sunrise': 1617852457,
#           'sunset': 1617898579,
#           'type': 1},
#   'timezone': 10800,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 300, 'speed': 3.6}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 48.5833, 'lon': -4},
#   'dt': 1617907624,
#   'id': 2991771,
#   'main': {'feels_like': 279.51,
#            'humidity': 76,
#            'pressure': 1019,
#            'temp': 281.11,
#            'temp_max': 282.04,
#            'temp_min': 280.15},
#   'name': 'Arrondissement de Morlaix',
#   'sys': {'country': 'FR',
#           'id': 6561,
#           'sunrise': 1617860349,
#           'sunset': 1617908163,
#           'type': 1},
#   'timezone': 7200,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 350, 'speed': 2.57}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 46.4333, 'lon': 26.4},
#   'dt': 1617907625,
#   'id': 686090,
#   'main': {'feels_like': 277.1,
#            'humidity': 48,
#            'pressure': 1022,
#            'temp': 277.1,
#            'temp_max': 277.15,
#            'temp_min': 277.04},
#   'name': 'Asău',
#   'sys': {'country': 'RO',
#           'id': 6909,
#           'sunrise': 1617853222,
#           'sunset': 1617900702,
#           'type': 1},
#   'timezone': 10800,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 0, 'speed': 0.51}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 56.3444, 'lon': 114.8794},
#   'dt': 1617907625,
#   'id': 2015701,
#   'main': {'feels_like': 268.9,
#            'grnd_level': 956,
#            'humidity': 90,
#            'pressure': 1020,
#            'sea_level': 1020,
#            'temp': 270.74,
#            'temp_max': 270.74,
#            'temp_min': 270.74},
#   'name': 'Taksimo',
#   'sys': {'country': 'RU', 'sunrise': 1617917393, 'sunset': 1617966835},
#   'timezone': 28800,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 241, 'gust': 1.7, 'speed': 1.36}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 96},
#   'cod': 200,
#   'coord': {'lat': 4.6482, 'lon': 22.2633},
#   'dt': 1617907626,
#   'id': 239300,
#   'main': {'feels_like': 294.97,
#            'grnd_level': 956,
#            'humidity': 96,
#            'pressure': 1010,
#            'sea_level': 1010,
#            'temp': 294.29,
#            'temp_max': 294.29,
#            'temp_min': 294.29},
#   'name': 'Gambo',
#   'rain': {'1h': 0.37},
#   'sys': {'country': 'CF', 'sunrise': 1617856010, 'sunset': 1617899898},
#   'timezone': 3600,
#   'visibility': 10000,
#   'weather': [{'description': 'light rain',
#                'icon': '10n',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 182, 'gust': 0.88, 'speed': 0.43}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': -13.8833, 'lon': 167.55},
#   'dt': 1617907626,
#   'id': 2134814,
#   'main': {'feels_like': 304.5,
#            'grnd_level': 997,
#            'humidity': 71,
#            'pressure': 1009,
#            'sea_level': 1009,
#            'temp': 301.42,
#            'temp_max': 301.42,
#            'temp_min': 301.42},
#   'name': 'Sola',
#   'sys': {'country': 'VU', 'sunrise': 1617908115, 'sunset': 1617950836},
#   'timezone': 39600,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 45, 'gust': 4.52, 'speed': 4.34}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 68.3499, 'lon': -133.7218},
#   'dt': 1617907626,
#   'id': 5983607,
#   'main': {'feels_like': 241.06,
#            'humidity': 70,
#            'pressure': 1019,
#            'temp': 250.64,
#            'temp_max': 251.15,
#            'temp_min': 250.15},
#   'name': 'Inuvik',
#   'sys': {'country': 'CA',
#           'id': 1029,
#           'sunrise': 1617888606,
#           'sunset': 1617942161,
#           'type': 1},
#   'timezone': -21600,
#   'visibility': 1633,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 300, 'speed': 4.12}}]

# %%
weather_df = pd.DataFrame({
    'City': city_name,
    'Country': country_name,
    'Lat': latitude,
    'Lng': longitude,
    'Temperature': temperature,
    'Humidity': humidity,
    'Cloudiness': clouds,
    'Wind (MPH)': wind
})

weather_df
# Out:
#          City Country      Lat       Lng  Temperature  Humidity  Cloudiness  \
# 0       Vaini      TO -21.2000 -175.2000       294.15        94          20
# 1    Tasiilaq      GL  65.6145  -37.6368       267.15        68          20
# 2     Itarema      BR  -2.9248  -39.9167       301.64        74          91
# 3      Hobart      AU -42.8794  147.3294       283.58        71           8
# 4     Rikitea      PF -23.1203 -134.9692       297.70        65          27
# ..        ...     ...      ...       ...          ...       ...         ...
# 549      Asău      RO  46.4333   26.4000       277.10        48          40
# 550   Taksimo      RU  56.3444  114.8794       270.74        90         100
# 551     Gambo      CF   4.6482   22.2633       294.29        96          96
# 552      Sola      VU -13.8833  167.5500       301.42        71         100
# 553    Inuvik      CA  68.3499 -133.7218       250.64        70         100
#
#      Wind (MPH)
# 0          1.54
# 1          2.06
# 2          7.61
# 3          4.12
# 4          1.05
# ..          ...
# 549        0.51
# 550        1.36
# 551        0.43
# 552        4.34
# 553        4.12
#
# [554 rows x 8 columns]

# %%
# function to convert 'Temperature' column from Kelvin to Farenheit
def Kelvin_to_Farenheit(kelvin):
    farenheit = (kelvin-273.15)*(9/5)+32
    return farenheit

# %%
weather_df['Temperature'] = Kelvin_to_Farenheit(weather_df['Temperature'])
weather_df
# Out:
#          City Country      Lat       Lng  Temperature  Humidity  Cloudiness  \
# 0       Vaini      TO -21.2000 -175.2000       69.800        94          20
# 1    Tasiilaq      GL  65.6145  -37.6368       21.200        68          20
# 2     Itarema      BR  -2.9248  -39.9167       83.282        74          91
# 3      Hobart      AU -42.8794  147.3294       50.774        71           8
# 4     Rikitea      PF -23.1203 -134.9692       76.190        65          27
# ..        ...     ...      ...       ...          ...       ...         ...
# 549      Asău      RO  46.4333   26.4000       39.110        48          40
# 550   Taksimo      RU  56.3444  114.8794       27.662        90         100
# 551     Gambo      CF   4.6482   22.2633       70.052        96          96
# 552      Sola      VU -13.8833  167.5500       82.886        71         100
# 553    Inuvik      CA  68.3499 -133.7218       -8.518        70         100
#
#      Wind (MPH)
# 0          1.54
# 1          2.06
# 2          7.61
# 3          4.12
# 4          1.05
# ..          ...
# 549        0.51
# 550        1.36
# 551        0.43
# 552        4.34
# 553        4.12
#
# [554 rows x 8 columns]

# %%
weather_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Temperature    float64
# Humidity         int64
# Cloudiness       int64
# Wind (MPH)     float64
# dtype: object

# %% [markdown]
# ##### Analysis of 'Temperature (Farenheit) v. Latitude'

# %%
# Scatter Plot - Temperature (Farenheit) v. Latitude
x_values = weather_df['Lat']
y_values = weather_df['Temperature']
plt.scatter(x_values, y_values)
plt.title('Temperature v. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Temperature (Farenheit)')
plt.savefig(f'visualizations/TempLat.png')
plt.show()

# %% [markdown]
# From the weather data [weather_df], the code above is plotting <b>cities' temperatures in relation to their latitude</b> - <em>latitude meaning their north-south position on the Earth's surface</em>.

# %% [markdown]
# ##### Analysis of 'Humidity (%) v. Latitude'

# %%
# Scatter Plot - Humidity (%) v. Latitude
x_values = weather_df['Lat']
y_values = weather_df['Humidity']
plt.scatter(x_values, y_values)
plt.title('Humidity v. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.savefig(f'visualizations/HumLat.png')
plt.show()

# %% [markdown]
# Using the same data, this code is plotting <b>cities' humidity in relation to their latitude</b>.

# %% [markdown]
# ##### Analysis of 'Cloudiness(%) v. Latitude'

# %%
# Scatter Plot - Cloudiness (%) v. Latitude
x_values = weather_df['Lat']
y_values = weather_df['Cloudiness']
plt.scatter(x_values, y_values)
plt.title('Cloudiness v. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.savefig(f'visualizations/CloudLat.png')
plt.show()

# %% [markdown]
# This code is plotting the <b>cities' cloudiness in relation to their latitude</b>.

# %% [markdown]
# ##### Analysis of  'Wind Speed (mph) v. Latitude'

# %%
# Scatter Plot - Wind Speed (mph)) v. Latitude
x_values = weather_df['Lat']
y_values = weather_df['Wind (MPH)']
plt.scatter(x_values, y_values)
plt.title('Wind Speed v. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig(f'visualizations/WindLat.png')
plt.show()

# %% [markdown]
# And finally, the <b>cities' wind speed in relation to their latitude</b>.

# %% [markdown]
# ### Linear Regressions: Northern Hemisphere v. Southern Hemisphere

# %%
# Northern Hemisphere Data Frame
northWeather_df = weather_df.loc[(
    weather_df['Lat'] >= 0)]
northWeather_df
# Out:
#                           City Country      Lat       Lng  Temperature  \
# 1                     Tasiilaq      GL  65.6145  -37.6368       21.200
# 6                    Hong Kong      HK  22.2855  114.1577       67.316
# 8                     Khatanga      RU  71.9667  102.5000      -24.700
# 10                  Chokurdakh      RU  70.6333  147.9167      -12.064
# 11                      Bethel      US  41.3712  -73.4140       70.286
# ..                         ...     ...      ...       ...          ...
# 548  Arrondissement de Morlaix      FR  48.5833   -4.0000       46.328
# 549                       Asău      RO  46.4333   26.4000       39.110
# 550                    Taksimo      RU  56.3444  114.8794       27.662
# 551                      Gambo      CF   4.6482   22.2633       70.052
# 553                     Inuvik      CA  68.3499 -133.7218       -8.518
#
#      Humidity  Cloudiness  Wind (MPH)
# 1          68          20        2.06
# 6          83         100        0.89
# 8         100         100        1.18
# 10         95         100        2.13
# 11         37           1        3.09
# ..        ...         ...         ...
# 548        76          75        2.57
# 549        48          40        0.51
# 550        90         100        1.36
# 551        96          96        0.43
# 553        70         100        4.12
#
# [374 rows x 8 columns]

# %%
# Southern Hemisphere Data Frame
southWeather_df = weather_df.loc[(
    weather_df['Lat'] < 0)]
southWeather_df
# Out:
#         City Country      Lat       Lng  Temperature  Humidity  Cloudiness  \
# 0      Vaini      TO -21.2000 -175.2000       69.800        94          20
# 2    Itarema      BR  -2.9248  -39.9167       83.282        74          91
# 3     Hobart      AU -42.8794  147.3294       50.774        71           8
# 4    Rikitea      PF -23.1203 -134.9692       76.190        65          27
# 5    El Alto      PE  -4.2714  -81.2147       91.400        49           0
# ..       ...     ...      ...       ...          ...       ...         ...
# 534   Mwense      ZM -10.3845   28.6980       65.534        93          16
# 536  Vilhena      BR -12.7406  -60.1458       75.200        94          40
# 537  Chancay      PE -11.5714  -77.2672       72.842        68           0
# 546      Vao      NC -22.6667  167.4833       77.522        80          44
# 552     Sola      VU -13.8833  167.5500       82.886        71         100
#
#      Wind (MPH)
# 0          1.54
# 2          7.61
# 3          4.12
# 4          1.05
# 5          6.17
# ..          ...
# 534        1.65
# 536        2.06
# 537        3.09
# 546        9.98
# 552        4.34
#
# [180 rows x 8 columns]

# %% [markdown]
# #### Temperature (Farenheit) Linear Regressions

# %%
# Linear Regression - Temperature (Farenheit) v. Latitude (Northern Hemisphere)
x_values = northWeather_df['Lat']
y_values = northWeather_df['Temperature']
plt.scatter(x_values, y_values)
plt.title('Temperature Linear Regression - Northern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Temperature (Farenheit)')
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
plt.savefig(f'visualizations/TempLinreg_North.png')
plt.show()
print(f"The r-value is: {rvalue**2}")

# Linear Regression - Temperature (Farenheit) v. Latitude (Southern Hemisphere)
x_values = southWeather_df['Lat']
y_values = southWeather_df['Temperature']
plt.scatter(x_values, y_values)
plt.title('Temperature Linear Regression - Southern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Temperature (Farenheit)')
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
plt.savefig(f'visualizations/TempLinreg_South.png')
plt.show()
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.7620928030619483
# The r-value is: 0.45297735726549687

# %% [markdown]
# #### Humidity (%) Linear Regressions

# %%
# Linear Regression - Humidity (%) v. Latitude (Northern Hemisphere)
x_values = northWeather_df['Lat']
y_values = northWeather_df['Humidity']
plt.scatter(x_values, y_values)
plt.title('Humidity Linear Regression - Northern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
plt.savefig(f'visualizations/HumLinreg_North.png')
plt.show()
print(f"The r-value is: {rvalue**2}")

# Linear Regression - Humidity (%) v. Latitude (Southern Hemisphere)
x_values = southWeather_df['Lat']
y_values = southWeather_df['Humidity']
plt.scatter(x_values, y_values)
plt.title('Humidity Linear Regression - Southern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
plt.savefig(f'visualizations/HumLinreg_South.png')
plt.show()
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.06320770768954329
# The r-value is: 0.0009849184227168426

# %% [markdown]
# #### Cloudiness (%) Linear Regression

# %%
# Linear Regression - Cloudiness (%) v. Latitude (Northern Hemisphere)
x_values = northWeather_df['Lat']
y_values = northWeather_df['Cloudiness']
plt.scatter(x_values, y_values)
plt.title('Cloudiness Linear Regression - Northern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
plt.savefig(f'visualizations/CloudLinreg_North.png')
plt.show()
print(f"The r-value is: {rvalue**2}")

# Linear Regression - Cloudiness (%) v. Latitude (Southern Hemisphere)
x_values = southWeather_df['Lat']
y_values = southWeather_df['Cloudiness']
plt.scatter(x_values, y_values)
plt.title('Cloudiness Linear Regression - Southern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
plt.savefig(f'visualizations/CloudLinreg_South.png')
plt.show()
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.04311715189361874
# The r-value is: 0.07913976325221578

# %% [markdown]
# #### Wind Speed (mph) Linear Regressions

# %%
# Linear Regression - Wind Speed (mph) v. Latitude (Northern Hemisphere)
x_values = northWeather_df['Lat']
y_values = northWeather_df['Wind (MPH)']
plt.scatter(x_values, y_values)
plt.title('Wind Speed Linear Regression - Northern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
plt.savefig(f'visualizations/WindLinreg_North.png')
plt.show()
print(f"The r-value is: {rvalue**2}")

# Linear Regression - Wind Speed (mph) v. Latitude (Southern Hemisphere)
x_values = southWeather_df['Lat']
y_values = southWeather_df['Wind (MPH)']
plt.scatter(x_values, y_values)
plt.title('Wind Speed Linear Regression - Southern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
plt.savefig(f'visualizations/WindLinreg_South.png')
plt.show()
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.021881990306120477
# The r-value is: 0.005831764240071864

# %% [markdown]
# #### Save Data Frames as CSVs

# %%
# Weather Data Frame
weather_df_csv = weather_df.to_csv(index=False)
weatherData_csv = open("data/weather_df.csv", "w", encoding='utf-8')
weatherData_csv.write(weather_df_csv)
weatherData_csv.close()

# %%
# Northern Hemisphere - Weather Data Frame
northWeather_df_csv = northWeather_df.to_csv(index=False)
northWeatherData_csv = open("data/northWeather_df.csv", "w", encoding='utf-8')
northWeatherData_csv.write(northWeather_df_csv)
northWeatherData_csv.close()

# %%
# Southern Hemisphere - Weather Data Frame
southWeather_df_csv = southWeather_df.to_csv(index=False)
southWeatherData_csv = open("data/southWeather_df.csv", "w", encoding='utf-8')
southWeatherData_csv.write(southWeather_df_csv)
southWeatherData_csv.close()
